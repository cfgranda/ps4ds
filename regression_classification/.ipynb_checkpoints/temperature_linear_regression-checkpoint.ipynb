# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
from os import listdir
import seaborn as sns
from scipy import stats
from numpy import linalg as LA
from sklearn.linear_model import LinearRegression,RidgeCV,LassoCV
from numpy.random import default_rng
import cartopy
import cartopy.crs as ccrs
import cartopy.feature as cfeature
rng = default_rng(2023)

font_size = 30
font_size_ticks = 25

np.set_printoptions(precision=5)

def process_name(x):
    x = x[14:]
    x = x[:-7]
    x = x.translate(str.maketrans('','','_1234567890'))
    return x[2:] + ", " + x[:2]

def state(x):
    x = x[14:]
    return x[:2]

str_path = "../data/weather/"

file_name_temperatures_2015 = str_path + "temperatures_2015.npy"
file_name_temperatures_2016 = str_path + "temperatures_2016.npy"

data_matrix_2015 = np.load(file_name_temperatures_2015)
data_matrix_2016 = np.load(file_name_temperatures_2016)

file_name_list = listdir(str_path + "hourly/2015/")
file_name_list.sort()

latitudes = []
longitudes = []
for ind,name in enumerate(file_name_list):
    print(ind)
    print(name)
    if name[0] != '.':
        data_aux = np.loadtxt(str_path + "hourly/2015/" + name, usecols=range(14))
        print("longitude: " + str(data_aux[0,6]))
        print("latitude: " + str(data_aux[0,7]))
        longitudes.append(data_aux[0,6])
        latitudes.append(data_aux[0,7])
# Out:
# 0
# .DS_Store
# 1
# CRNH0203-2015-AL_Brewton_3_NNE.txt
# longitude: -87.05
# latitude: 31.14
# 2
# CRNH0203-2015-AL_Clanton_2_NE.txt
# longitude: -86.61
# latitude: 32.85
# 3
# CRNH0203-2015-AL_Courtland_2_WSW.txt
# longitude: -87.35
# latitude: 34.66
# 4
# CRNH0203-2015-AL_Cullman_3_ENE.txt
# longitude: -86.8
# latitude: 34.2
# 5
# CRNH0203-2015-AL_Fairhope_3_NE.txt
# longitude: -87.88
# latitude: 30.55
# 6
# CRNH0203-2015-AL_Gadsden_19_N.txt
# longitude: -85.96
# latitude: 34.29
# 7
# CRNH0203-2015-AL_Gainesville_2_NE.txt
# longitude: -88.14
# latitude: 32.84
# 8
# CRNH0203-2015-AL_Greensboro_2_WNW.txt
# longitude: -87.62
# latitude: 32.72
# 9
# CRNH0203-2015-AL_Highland_Home_2_S.txt
# longitude: -86.31
# latitude: 31.92
# 10
# CRNH0203-2015-AL_Muscle_Shoals_2_N.txt
# longitude: -87.64
# latitude: 34.77
# 11
# CRNH0203-2015-AL_Northport_2_S.txt
# longitude: -87.59
# latitude: 33.21
# 12
# CRNH0203-2015-AL_Russellville_4_SSE.txt
# longitude: -87.71
# latitude: 34.45
# 13
# ...

# %%
def remove_faulty_measurements(data,verbose):
    min_val = -100 # We assume temperatures cannot be lower than -100
    for ind in range(len(data)):
        median = np.median(data[data > min_val])
        if data[ind] < min_val:
            if verbose:
                print(str(ind) + ": " + str(data[ind]))
            aux_ind = ind-1
            while aux_ind > 0:
                if data[aux_ind] > min_val:
                    data[ind] = data[aux_ind]
                    if verbose:
                        print("changed entry " + str(aux_ind) + ": " + str(data[ind]))
                    break
                else:
                    ind -= 1
    return data

verbose = True
for ind in range(data_matrix_2015.shape[1]):
    print(ind)
    data_matrix_2015[:,ind] = remove_faulty_measurements(data_matrix_2015[:,ind],verbose)
    data_matrix_2016[:,ind] = remove_faulty_measurements(data_matrix_2016[:,ind],verbose)
# Out:
# 0
# 110: -9999.0
# changed entry 109: 3.4
# 111: -9999.0
# changed entry 110: 3.4
# 422: -9999.0
# changed entry 421: 7.9
# 2629: -9999.0
# changed entry 2628: 20.5
# 4309: -9999.0
# changed entry 4308: 22.0
# 5825: -9999.0
# changed entry 5824: 29.9
# 6829: -9999.0
# changed entry 6828: 12.2
# 6830: -9999.0
# changed entry 6829: 12.2
# 6831: -9999.0
# changed entry 6830: 12.2
# 6834: -9999.0
# changed entry 6833: 25.4
# 8677: -9999.0
# changed entry 8676: 22.6
# 1
# 95: -9999.0
# changed entry 94: 10.2
# 96: -9999.0
# changed entry 95: 10.2
# 2613: -9999.0
# changed entry 2612: 25.2
# 8662: -9999.0
# changed entry 8661: 23.0
# 2
# 1628: -9999.0
# changed entry 1627: 13.8
# 8249: -9999.0
# changed entry 8248: 12.2
# 8688: -9999.0
# changed entry 8687: 16.9
# 3
# 6537: -9999.0
# changed entry 6536: 19.2
# 4
# 4050: -9999.0
# changed entry 4049: 30.8
# 5918: -9999.0
# changed entry 5917: 26.8
# 5919: -9999.0
# changed entry 5918: 26.8
# 5920: -9999.0
# changed entry 5919: 26.8
# ...

# %%
print(data_matrix_2015.shape)
print(data_matrix_2016.shape)

ind_response = 55
print( "Response is " + process_name(str(file_name_list[ind_response+1])))
y_all = data_matrix_2015[:,ind_response]
y_2016 = data_matrix_2016[:,ind_response]
n_2016 = len(y_2016)
longitude_y = longitudes[ind_response]
latitude_y = latitudes[ind_response]

ind_X = np.hstack((np.arange(0,ind_response),np.arange(ind_response+1,data_matrix_2015.shape[1])))
XT_all = data_matrix_2015[:,ind_X]
XT_2016 = data_matrix_2016[:,ind_X]
longitudes_X = np.array(longitudes)[ind_X]
latitudes_X = np.array(latitudes)[ind_X]

d = XT_all.shape[1]

n_test = int(1e3)

aux_ind = np.random.permutation(range(data_matrix_2015.shape[0]))
ind_test = aux_ind[:n_test]
XT_test = X_all[ind_test,:]
y_test = y_all[ind_test]
ind_train = aux_ind[n_test:]
XT_train = X_all[ind_train,:]
y_train = y_all[ind_train]
print(ind_X[:5])
print(X_train.shape)
print(y_train.shape)
n_train = X_train.shape[0]
print("Number of features",d)
print("Number of training examples",n_train)
# Out:
# (8760, 134)
# (8784, 134)
# Response is Versailles, KY
# [0 1 2 3 4]
# (7760, 133)
# (7760,)
# Number of features 133
# Number of training examples 7760

# %%
print(alphas_val)
# Out:
# [ 100.       104.81131  109.85411  115.13954  120.67926  126.48552
#   132.57114  138.94955  145.63485  152.6418   159.98587  167.68329
#   175.75106  184.207    193.06977  202.35896  212.09509  222.29965
#   232.99518  244.20531  255.95479  268.26958  281.17687  294.70517
#   308.88436  323.74575  339.32218  355.64803  372.75937  390.69399
#   409.49151  429.19343  449.84327  471.48664  494.17134  517.94747
#   542.86754  568.9866   596.36233  625.05519  655.12856  686.64885
#   719.68567  754.31201  790.60432  828.64277  868.51137  910.29818
#   954.09548 1000.     ]

# %%
n_vals = np.logspace(np.log10(d),np.log10(n_train)).astype(int)
print(n_vals)
n_alpha_lasso = 200
alphas_val = np.logspace(1, 4, n_alphas)

n_len = len(n_vals)
cov_matrix_eigvals = np.zeros((d,n_len)) 

OLS_coeffs_array = np.zeros((d,n_len)) 
OLS_training_error = np.zeros(n_len)
OLS_test_error = np.zeros(n_len)
OLS_test_error_2016 = np.zeros(n_len)
ridge_coeffs_array = np.zeros((d,n_len)) 
ridge_training_error = np.zeros(n_len)
ridge_test_error = np.zeros(n_len)
ridge_test_error_2016 = np.zeros(n_len)
ridge_alphas = np.zeros(n_len) 
lasso_coeffs_array = np.zeros((d,n_len)) 
lasso_training_error = np.zeros(n_len)
lasso_test_error = np.zeros(n_len)
lasso_test_error_2016 = np.zeros(n_len)
lasso_alphas = np.zeros(n_len) 

for ind_n,n in enumerate(n_vals):
    XT_train_n = XT_train[:n,:]
    y_train_n = y_train[:n]
    
    cov_matrix = np.cov(XT_train_n.T,ddof=1)
    eigvals_cov_matrix,eigvecs_cov_matrix = np.linalg.eig(cov_matrix)
    cov_matrix_eigvals[:,ind_n] = np.sort(eigvals_cov_matrix)

    OLS_model_n = LinearRegression().fit(XT_train_n, y_train_n)
    OLS_coeffs_array[:,ind_n] = OLS_model_n.coef_
    OLS_training_error[ind_n] = np.sqrt(np.sum((y_train_n - OLS_model_n.predict(XT_train_n))**2) / n )
    #training_error[ind_n] = OLS_model_n.score(XT_train_n, y_train_n)
    OLS_test_error[ind_n] = np.sqrt(np.sum((y_test - OLS_model_n.predict(XT_test))**2) / n_test )
    #test_error[ind_n] = OLS_model_n.score(XT_test, y_test)
    OLS_test_error_2016[ind_n] = np.sqrt(np.sum((y_2016 - OLS_model_n.predict(XT_2016))**2) / n_2016 )
    #test_error_2016[ind_n] = OLS_model_n.score(XT_2016, y_2016)
    
    ridge_model_n = RidgeCV(alphas=alphas_val).fit(XT_train_n, y_train_n)
    coeffs = ridge_model_n.coef_
    ridge_coeffs_array[:,ind_n] = ridge_model_n.coef_
    ridge_training_error[ind_n] = np.sqrt(np.sum((y_train_n - ridge_model_n.predict(XT_train_n))**2) / n )
    ridge_test_error[ind_n] = np.sqrt(np.sum((y_test - ridge_model_n.predict(XT_test))**2) / n_test )
    ridge_test_error_2016[ind_n] = np.sqrt(np.sum((y_2016 - ridge_model_n.predict(XT_2016))**2) / n_2016 )
    ridge_alphas[ind_n] = ridge_model_n.alpha_
    
    lasso_model_n = LassoCV(n_alphas=n_alpha_lasso).fit(XT_train_n, y_train_n)
    coeffs = ridge_model_n.coef_
    lasso_coeffs_array[:,ind_n] = lasso_model_n.coef_
    lasso_training_error[ind_n] = np.sqrt(np.sum((y_train_n - lasso_model_n.predict(XT_train_n))**2) / n )
    lasso_test_error[ind_n] = np.sqrt(np.sum((y_test - lasso_model_n.predict(XT_test))**2) / n_test )
    lasso_test_error_2016[ind_n] = np.sqrt(np.sum((y_2016 - lasso_model_n.predict(XT_2016))**2) / n_2016 )
    lasso_alphas[ind_n] = lasso_model_n.alpha_
# Out:
# [ 133  144  157  170  185  201  218  237  258  280  304  331  360  391
#   425  461  501  545  592  643  699  759  825  897  974 1058 1150 1250
#  1358 1475 1603 1742 1893 2056 2234 2428 2638 2866 3114 3384 3676 3995
#  4340 4716 5124 5567 6049 6573 7142 7760]
# /Users/carlos/opt/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# /Users/carlos/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.2708892244386973, tolerance: 0.8352750795454545
#   positive)
# ...

# %%
xtick_vals = [200,500,1000,2000,5000]
sigma_est = training_error[-1]
theoretical_prediction_train = sigma_est * np.sqrt(1-d/n_vals)
theoretical_prediction_test = sigma_est * np.sqrt(1+d/(n_vals-1))
fig = plt.figure(figsize = (13,10)) 
plt.semilogx(n_vals,OLS_training_error,"o")
plt.semilogx(n_vals,theoretical_prediction_train)
plt.semilogx(n_vals,OLS_test_error,"o")
plt.semilogx(n_vals,OLS_test_error_2016,"o")
plt.semilogx(n_vals,theoretical_prediction_test)
plt.xticks(fontsize=font_size_ticks) 
plt.yticks(fontsize=font_size_ticks)
plt.ylim([0,5])
ax = plt.gca()
ax.set_xscale('log')
ax.set_xticks(xtick_vals)
ax.get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
#plt.xlim([0,5])
#plt.xlabel('Adult smokers (age-adjusted %)',fontsize=font_size,labelpad = 20)
#plt.ylabel('Median household income (1000$)',fontsize=font_size,labelpad = 15)
#plt.savefig('plots/US_counties_income_smoking_mortality.pdf',bbox_inches="tight")

fig = plt.figure(figsize = (13,10)) 
for ind_feature in range(d):
    plt.semilogx(n_vals,coeffs_array[ind_feature,:])
plt.ylim([-1,1])
ax = plt.gca()
ax.set_xscale('log')
ax.set_xticks(xtick_vals)
ax.get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())

# %%
xtick_vals = [200,500,1000,2000,5000]
sigma_est = training_error[-1]
theoretical_prediction_train = sigma_est * np.sqrt(1-d/n_vals)
theoretical_prediction_test = sigma_est * np.sqrt(1+d/(n_vals-1))
fig = plt.figure(figsize = (13,10)) 
plt.semilogx(n_vals,OLS_training_error,"o")
plt.semilogx(n_vals,OLS_test_error,"o")
plt.semilogx(n_vals,OLS_test_error_2016,"o")
plt.semilogx(n_vals,ridge_training_error,"x")
plt.semilogx(n_vals,ridge_test_error,"x")
plt.semilogx(n_vals,ridge_test_error_2016,"x")
plt.semilogx(n_vals,lasso_training_error,"d")
plt.semilogx(n_vals,lasso_test_error,"d")
plt.semilogx(n_vals,lasso_test_error_2016,"d")


plt.xticks(fontsize=font_size_ticks) 
plt.yticks(fontsize=font_size_ticks)
plt.ylim([0,5])
ax = plt.gca()
ax.set_xscale('log')
ax.set_xticks(xtick_vals)
ax.get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())

fig = plt.figure(figsize = (13,10)) 
#for ind in range(d):
#    plt.loglog(n_vals,cov_matrix_eigvals[ind,:],'o')
#plt.ylim([1e-3,2e-1])
plt.plot(n_vals,ridge_alphas/n_vals,'o')
ax = plt.gca()
ax.set_xscale('log')
ax.set_xticks(xtick_vals)
ax.get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())

fig = plt.figure(figsize = (13,10)) 
#for ind in range(d):
#    plt.loglog(n_vals,cov_matrix_eigvals[ind,:],'o')
#plt.ylim([1e-3,2e-1])
plt.plot(n_vals,lasso_alphas,'o')
ax = plt.gca()
ax.set_xscale('log')
ax.set_xticks(xtick_vals)
ax.get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())

# %%
coeff_marker = 40
largest_coeff_ind = np.argsort(coeffs_array[:,-1])[-1] 
second_largest_coeff_ind = np.argsort(coeffs_array[:,-1])[-2] 

fig = plt.figure(figsize=(15,6))
ax = fig.add_axes([0, 0, 1, 1], projection=ccrs.LambertConformal())
ax.set_extent([-120, -77.5, 24, 45], ccrs.Geodetic())

ax.coastlines()
ax.plot(longitude_y,latitude_y, '*', markersize=20,color="black",markeredgewidth=2,
        markerfacecolor="white",transform=ccrs.Geodetic(),label='Response')
plt.text(longitude_y+1,latitude_y-0.5,"Versailles",transform=ccrs.Geodetic(),fontsize=20)
# plt.annotate("Versailles",
#             xy=(longitude_y,latitude_y), xycoords='data',
#             #xytext=(longitudes[ind_temp]+x_shift_2[ind],latitudes[ind_temp]+y_shift_2[ind]),fontsize=font_size_ticks,
#             #    arrowprops=dict(facecolor='black', shrink=0.05)
#             )
for ind in range(n_features):
    if coeffs[ind] > 0:
        ax.plot(longitudes_X[ind],latitudes_X[ind],'o',ms=coeff_marker*coeffs_array[ind,-1],color="black",markeredgewidth=2,
                 markerfacecolor="white",transform=ccrs.Geodetic())
    else:
        ax.plot(longitudes_X[ind],latitudes_X[ind],'o',ms=-coeff_marker*coeffs_array[ind,-1],markeredgecolor="black",markeredgewidth=2,
                 markerfacecolor="black",transform=ccrs.Geodetic())
plt.ylabel('Latitude',fontsize=font_size,labelpad=10)
plt.xlabel('Longitude',fontsize=font_size,labelpad=10)
plt.savefig('plots/OLS_coeffs_map.pdf',bbox_inches="tight")

# %%
fig = plt.figure(figsize = (13,10)) 
#for ind in range(d):
#    plt.loglog(n_vals,cov_matrix_eigvals[ind,:],'o')
#plt.ylim([1e-3,2e-1])
plt.plot(n_vals,cov_matrix_eigvals[0,:],'o')
ax = plt.gca()
ax.set_xscale('log')
ax.set_xticks(xtick_vals)
ax.get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())

# %%
linear_model = LinearRegression().fit(X_train, y_train)
coeffs = linear_model.coef_
print("Coefficients: " + str(np.sort(coeffs)))
print("Intercept: " + str(linear_model.intercept_))
# print(linear_model.score(X_train,y_train))
# print(linear_model.score(X_test,y_test))
# Out:
# Coefficients: [-2.31511e-01 -2.07034e-01 -1.71653e-01 -1.55709e-01 -1.32730e-01
#  -1.22032e-01 -1.07962e-01 -1.00985e-01 -9.84610e-02 -8.60324e-02
#  -8.54526e-02 -8.40035e-02 -7.93698e-02 -7.64007e-02 -7.56699e-02
#  -7.49313e-02 -7.15577e-02 -6.92159e-02 -6.83213e-02 -6.79394e-02
#  -6.77010e-02 -6.68282e-02 -6.67465e-02 -6.56288e-02 -6.49637e-02
#  -6.34907e-02 -6.26934e-02 -5.98196e-02 -5.31892e-02 -4.82159e-02
#  -4.81628e-02 -4.63884e-02 -4.62305e-02 -4.36686e-02 -4.26349e-02
#  -4.21292e-02 -4.20146e-02 -3.99476e-02 -3.97635e-02 -3.94207e-02
#  -3.43838e-02 -3.39228e-02 -3.31217e-02 -3.29153e-02 -2.78962e-02
#  -2.72721e-02 -2.72655e-02 -2.67494e-02 -2.53147e-02 -2.35745e-02
#  -2.23296e-02 -2.14613e-02 -2.09690e-02 -1.87632e-02 -1.74314e-02
#  -1.54604e-02 -1.44848e-02 -1.09663e-02 -7.73383e-03 -5.09505e-03
#  -3.36630e-03 -2.61065e-03 -2.37378e-03 -2.35119e-04  1.24214e-03
#   2.94829e-03  3.47551e-03  5.46565e-03  6.10607e-03  6.19830e-03
# ...

# %%
X_stds = np.std(X_train,axis=0)

# %%
coeff_marker = 40

fig = plt.figure(figsize=(15,6))
ax = fig.add_axes([0, 0, 1, 1], projection=ccrs.LambertConformal())
#ax.set_extent([-120, -76.5, 22, 45], ccrs.Geodetic())
ax.set_extent([-120, -77.5, 24, 45], ccrs.Geodetic())

ax.coastlines()
ax.plot(longitude_y,latitude_y, '*', markersize=20,color="black",markeredgewidth=2,
                  markerfacecolor="white",transform=ccrs.Geodetic(),label='Response')
for ind in range(n_features):
    if coeffs[ind] > 0:
        if ind == 1:
            #plt.plot(longitudes_X[ind],latitudes_X[ind],'o',ms=coeff_marker*coeffs[ind],color="black",markeredgewidth=2,
            #     markerfacecolor="white",label="Positive coefficient (radius proportional to magnitude)")
            ax.plot(longitudes_X[ind],latitudes_X[ind],'o',ms=coeff_marker*coeffs[ind],color="black",markeredgewidth=2,
                 markerfacecolor="white",label="Positive coefficient (radius proportional to magnitude)",transform=ccrs.Geodetic())
        else:
            ax.plot(longitudes_X[ind],latitudes_X[ind],'o',ms=coeff_marker*coeffs[ind],color="black",markeredgewidth=2,
                 markerfacecolor="white",transform=ccrs.Geodetic())
    else:
        if ind == 52:
            ax.plot(longitudes_X[ind],latitudes_X[ind],'o',ms=-coeff_marker*coeffs[ind],color="black",markeredgewidth=2,
                 markerfacecolor="black",label="Negative coefficient (radius proportional to magnitude)",transform=ccrs.Geodetic())
        else:
            ax.plot(longitudes_X[ind],latitudes_X[ind],'o',ms=-coeff_marker*coeffs[ind],markeredgecolor="black",markeredgewidth=2,
                 markerfacecolor="black",transform=ccrs.Geodetic())
# for ind in range(n_features):
#     if longitudes_X[ind] < -150:
#         if coeffs[ind] > 0:
#             plt.plot(longitudes_X[ind]+35,latitudes_X[ind]+5,'o',ms=coeff_marker*coeffs[ind],color="black",markeredgewidth=2,
#                      markerfacecolor="white")
#         else:
#             plt.plot(longitudes_X[ind]+35,latitudes_X[ind]+5,'o',ms=-coeff_marker*coeffs[ind],color="black",markeredgewidth=2,
#                      markerfacecolor="black")
#     else:
#         if coeffs[ind] > 0:
#             if ind == 1:
#                 plt.plot(longitudes_X[ind],latitudes_X[ind],'o',ms=coeff_marker*coeffs[ind],color="black",markeredgewidth=2,
#                      markerfacecolor="white",label="Positive coefficient (radius proportional to magnitude)")
#             else:
#                 plt.plot(longitudes_X[ind],latitudes_X[ind],'o',ms=coeff_marker*coeffs[ind],color="black",markeredgewidth=2,
#                      markerfacecolor="white")
#         else:
#             if ind == 52:
#                 plt.plot(longitudes_X[ind],latitudes_X[ind],'o',ms=-coeff_marker*coeffs[ind],color="black",markeredgewidth=2,
#                      markerfacecolor="black",label="Negative coefficient (radius proportional to magnitude)")
#             else:
#                 plt.plot(longitudes_X[ind],latitudes_X[ind],'o',ms=-coeff_marker*coeffs[ind],markeredgecolor="black",markeredgewidth=2,
#                      markerfacecolor="black")
plt.legend(fontsize=font_size_ticks-2,loc='upper center', bbox_to_anchor=(0.45, 1.3),
           fancybox=True, shadow=True, ncol=1)            
# plt.ylim([22,53])
# plt.xlim([-127,-65])
# plt.vlines(-115,22,28,lw=3,color="black")
# plt.hlines(28,-115,-127,lw=3,color="black")
# plt.xticks(fontsize=font_size_ticks) 
# plt.yticks(fontsize=font_size_ticks)
plt.ylabel('Latitude',fontsize=font_size,labelpad=10)
plt.xlabel('Longitude',fontsize=font_size,labelpad=10)
plt.savefig('plots/temperatures_map_coeffs.pdf',bbox_inches="tight")
