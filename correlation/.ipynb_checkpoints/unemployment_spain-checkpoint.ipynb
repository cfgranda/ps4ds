# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
from sklearn.linear_model import LinearRegression
import datetime
import math

font_size = 30
font_size_ticks = 25

data_all = pd.read_csv ("../data/unemployment_spain/unemployment_spain.csv")
data = data_all[data_all["Tourists"]>0]
print(data.columns)
temperature = data["Temperature"].values
tourists = data["Tourists"].values/1e6
unemployment = data['Unemployment'].values/1e6

tmin = np.min(temperature)-2
tmax = np.max(temperature)+2
t = np.linspace(tmin, tmax, 200)
umin = np.min(unemployment)
umax = np.max(unemployment)
# Out:
# Index(['Temperature', 'Tourists', 'Unemployment'], dtype='object')

# %%
data.corr()
# Out:
#               Temperature  Tourists  Unemployment
# Temperature      1.000000  0.602374     -0.205447
# Tourists         0.602374  1.000000     -0.346758
# Unemployment    -0.205447 -0.346758      1.000000

# %%
fig = plt.figure(figsize = (9,9)) 
plt.scatter(temperature,unemployment,c="black",s=160,cmap="gray",edgecolors='black',rasterized=True)
#plt.xlabel(r"$a$", fontsize=font_size,labelpad=10)
#h = plt.ylabel(r"$b$", fontsize=font_size,labelpad=15)
#h.set_rotation(0)
plt.xticks(fontsize=font_size_ticks) 
plt.yticks(fontsize=font_size_ticks)
#plt.ylim([ymin,ymax])
#plt.xlim([tmin,tmax])
plt.xlabel('Temperature',fontsize=font_size,labelpad = 10)
plt.ylabel('Unemployment (millions)',fontsize=font_size,labelpad = 15)
plt.savefig('plots/unemployment_temperature.pdf',bbox_inches="tight")

fig = plt.figure(figsize = (12,9)) 
im =plt.scatter(temperature,unemployment,c=tourists,s=160,cmap="gray",edgecolors='black',rasterized=True)
#plt.xlabel(r"$a$", fontsize=font_size,labelpad=10)
#h = plt.ylabel(r"$b$", fontsize=font_size,labelpad=15)
#h.set_rotation(0)
cbar = plt.colorbar(im,shrink=0.8)
cbar.ax.tick_params(labelsize=font_size_ticks,pad = 20)
cbar.set_label(label='Tourists (millions)',fontsize=font_size,labelpad = 20)
plt.xticks(fontsize=font_size_ticks) 
plt.yticks(fontsize=font_size_ticks)
#plt.ylim([ymin,ymax])
#plt.xlim([tmin,tmax])
plt.xlabel('Temperature',fontsize=font_size,labelpad = 10)
plt.ylabel('Unemployment (millions)',fontsize=font_size,labelpad = 15)
plt.savefig('plots/unemployment_temperature_tourists.pdf',bbox_inches="tight")

fig = plt.figure(figsize = (12,9)) 
im =plt.scatter(temperature,tourists,c=unemployment,s=160,cmap="gray",edgecolors='black',rasterized=True)
#plt.xlabel(r"$a$", fontsize=font_size,labelpad=10)
#h = plt.ylabel(r"$b$", fontsize=font_size,labelpad=15)
#h.set_rotation(0)
cbar = plt.colorbar(im,shrink=0.8)
cbar.ax.tick_params(labelsize=font_size_ticks,pad = 20)
cbar.set_label(label='Unemployment (millions)',fontsize=font_size,labelpad = 20)
plt.xticks(fontsize=font_size_ticks) 
plt.yticks(fontsize=font_size_ticks)
#plt.ylim([ymin,ymax])
#plt.xlim([tmin,tmax])
plt.xlabel('Temperature',fontsize=font_size,labelpad = 10)
plt.ylabel('Tourists (millions)',fontsize=font_size,labelpad = 15)
plt.savefig('plots/unemployment_temperature_tourists_unemployment.pdf',bbox_inches="tight")

# %%
rho_temperature_unemployment = np.corrcoef(temperature,unemployment)[0,1]
linear_model = np.mean(unemployment) + np.std(unemployment)*rho_temperature_unemployment * (t - np.mean(temperature))/np.std(temperature)
plt.figure(figsize=(9,9))
plt.scatter(temperature,unemployment,s=80,color="gray",rasterized=True)
plt.plot(t,linear_model ,lw=3,
         color="black",ls="dashed",label="Linear model")
plt.xticks(fontsize=font_size_ticks) 
plt.yticks(fontsize=font_size_ticks)
# plt.ylim([umin,umax])
plt.xlim([tmin,tmax])
plt.xlabel('Temperature',fontsize=font_size,labelpad = 20)
plt.ylabel('Unemployment (millions)',fontsize=font_size,labelpad = 15)
plt.legend(fontsize=font_size,framealpha=1)
plt.savefig('plots/unemployment_spain_temperature_linear_model.pdf',bbox_inches="tight")

# %%
linear_model_just_temp = LinearRegression().fit(temperature, unemployment)
print("Coefficients: " + str(linear_model.coef_))
print("Intercept: " + str(linear_model.intercept_))
print(linear_model.score(X,unemployment))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-63-2fd0defe17f3> in <module>
# ----> 1 linear_model_just_temp = LinearRegression().fit(temperature, unemployment)
#       2 print("Coefficients: " + str(linear_model.coef_))
#       3 print("Intercept: " + str(linear_model.intercept_))
#       4 print(linear_model.score(X,unemployment))
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/base.py in fit(self, X, y, sample_weight)
#     461         n_jobs_ = self.n_jobs
#     462         X, y = check_X_y(X, y, accept_sparse=['csr', 'csc', 'coo'],
# --> 463                          y_numeric=True, multi_output=True)
#     464
#     465         if sample_weight is not None and np.atleast_1d(sample_weight).ndim > 1:
#
# ...

# %%
standardized_temperature = (temperature - np.mean(temperature))/np.std(temperature)
standardized_tourists = (tourists - np.mean(tourists))/np.std(tourists)
standardized_unemployment = (unemployment - np.mean(unemployment))/np.std(unemployment)
X = np.array([[standardized_temperature,standardized_tourists]])[0].T
X.shape
reg = LinearRegression(fit_intercept=False).fit(X, standardized_unemployment)
print(reg.coef_)
# Out:
# [ 0.00538509 -0.35000144]

# %%
X = np.array([[temperature,tourists]])[0].T
linear_model = LinearRegression().fit(X, unemployment)
print("Coefficients: " + str(linear_model.coef_))
print("Intercept: " + str(linear_model.intercept_))
print(linear_model.score(X,unemployment))
print(linear_model.predict(np.array([[1,1]])))
# Out:
# Coefficients: [ 0.00025696 -0.03791735]
# Intercept: 3.8453849714720905
# 0.12025931289263603
# [3.80772457]

# %%
min_tourists = 0
max_tourists = 17
temperature_pred = np.linspace(tmin, tmax, 50)   
tourists_pred = np.linspace(min_tourists, max_tourists, 50)  

aux_temperature, aux_tourists = np.meshgrid(temperature_pred, tourists_pred)
model_input = np.array([aux_temperature.flatten(), aux_tourists.flatten()]).T

prediction = linear_model.predict(model_input)
reshaped_prediction = prediction.reshape(aux_temperature.shape)

v_max = np.max(unemployment)
v_min = np.min(unemployment)
fig = plt.figure(figsize = (15,12)) 
sc = plt.scatter(temperature,tourists,c=unemployment,s=120,cmap="gray_r",edgecolor='black',vmax = v_max,vmin = v_min,
            rasterized=True)
#im = plt.imshow(reshaped_prediction, cmap='gray_r', extent=[min_smoking, max_smoking,min_income,max_income], 
#                aspect="auto",origin='lower',vmax = v_max,vmin = v_min)
CS = plt.contour(reshaped_prediction,colors="black", extent=[min_temperature, max_temperature,min_tourists,max_tourists], 
                origin='lower',linewidths=3,linestyles="dashed",levels=4)
manual_locations = [(55, 15), (55, 10.5), (65, 6.7), (80, 3)]
plt.clabel(CS, fontsize=font_size_ticks, inline=1,fmt = '%1.1f',manual =manual_locations)#,ticks=Contourrange)
plt.xticks(fontsize=font_size_ticks) 
plt.yticks(fontsize=font_size_ticks)
plt.xlim([tmin,tmax])
ax = plt.gca()
ax.tick_params(axis='both', which='major', pad=15)
cbar = plt.colorbar(sc,shrink=1)
cbar.ax.tick_params(labelsize=font_size_ticks,pad = 20)
cbar.set_label(label='Unemployment (millions)',fontsize=font_size,labelpad = 20)
plt.xticks(fontsize=font_size_ticks) 
plt.yticks(fontsize=font_size_ticks)
plt.xlabel('Temperature',fontsize=font_size,labelpad = 20)
plt.ylabel('Tourists (millions)',fontsize=font_size,labelpad = 15)
plt.savefig('plots/unemployment_spain_contours.pdf',bbox_inches="tight")
plt.show()

# %%
# # Begin Date	2014-01-01 00:00
# temp_data_all = pd.read_csv ("../data/unemployment_spain/temperatures_noaa_rota.csv")
# #print(temp_data_all.columns[:100])
# temperature_hourly = temp_data_all["HourlyDryBulbTemperature"]
# dates = temp_data_all["DATE"]
# print(len(temperature_hourly))

# n_months = 12 * 8 + 10 # From Jan 2014 to October 2020
# years = np.arange(2014,2022+1)
# print(years)
# temperatures_total = np.zeros(n_months)
# month_counter = np.zeros(n_months)
# for ind in range(len(temperature)):
#     year = int(dates[ind][:4])
#     year_index = np.where(years == year)[0][0]
#     month = int(dates[ind][5:7])
#     index = year_index * 12 + month-1
#     # print(index)
#     if index >= n_months:
#         break
#     else:
#         temp = temperature_hourly[ind]
#         # print(temp)
#         # print(type(temp))
#         if not (isinstance(temp, str) and temp.isnumeric()==False):
#             temp_float = float(temp)
#             if math.isnan(temp_float)==False:
#                 temperatures_total[index] += temp_float
#                 month_counter[index] += 1
# print(month_counter)
# print(np.sum(month_counter))
# temperatures = np.round(temperatures_total / month_counter,2)
# print(temperatures)
# plt.figure()
# plt.plot(np.arange(n_months),temperatures)
# np.savetxt("unemployment_spain.csv", temperatures, delimiter=",")
