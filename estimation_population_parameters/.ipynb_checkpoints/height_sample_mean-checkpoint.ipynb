# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
from scipy import stats
from scipy.stats import norm
from numpy.random import default_rng
import matplotlib
matplotlib.rcParams['text.usetex'] = True
rng = default_rng(2021)

font_size = 30
font_size_legend = 22
font_size_ticks = 30

data = pd.read_csv ("../data/ANSUR II MALE Public.csv", encoding='latin-1')

stature = data['stature'] / 10.
N = len(stature)
population_mean = np.mean(stature)
population_std = np.std(stature)
print("N: " + str(len(stature)))
print("Population mean: " + str(population_mean))
print("Population standard deviation: " + str(population_std))
# Out:
# N: 4082
# Population mean: 175.62146006859493
# Population standard deviation: 6.854239043880039

# %%
n_bins = 30
x_min = 147
x_max = 200
# y_max = 0.067
tries = 3
n = 400

more_tries = int(1e4)
sample_means = np.zeros(more_tries)
for ind_tries in range(more_tries):
    samples = rng.choice(stature,n,replace=True)
    sample_means[ind_tries] = np.mean(samples)
plt.figure(figsize=(12,9))
plt.xticks([150,165,175.6,185,200],fontsize=font_size_ticks) 
plt.yticks(fontsize=font_size_ticks)
plt.hist(sample_means,bins=n_bins,color='dimgray',
              linewidth=2,density=False)
plt.xlim([x_min,x_max])
plt.ylabel(r"Count",fontsize=font_size,labelpad=20)
plt.xlabel('Height (cms)',fontsize=font_size,labelpad=20)
plt.savefig('plots/random_sampling_sample_mean_counts.pdf',bbox_inches="tight")

for ind in range(tries):
    samples = rng.choice(stature,n,replace=True)
    
    plt.figure(figsize=(12,9))
    plt.xticks(fontsize=font_size_ticks) 
    plt.yticks(fontsize=font_size_ticks)
    (aux_1, bins,aux_2) = plt.hist(stature,bins=n_bins,color='white', edgecolor='black',
              linewidth=2,label="Population")
    plt.hist(samples,bins=bins,color='lightgray', edgecolor='black',
              linewidth=2,label="Samples")
    plt.xlim([x_min,x_max])
    plt.ylabel("Count",fontsize=font_size,labelpad=20)
    plt.xlabel('Height (cms)',fontsize=font_size,labelpad=20)
    plt.legend(fontsize=font_size)
    plt.savefig('plots/random_sampling_stature_hist_' + str(ind) + '.pdf',bbox_inches="tight")
    
    print("Sample mean: " + str(np.mean(samples)))
# Out:
# Sample mean: 175.6465
# Sample mean: 175.351
# Sample mean: 175.39974999999998

# %%
tries = 20#int(1e2)
n_max = 1000
n_vals = np.arange(1,n_max,1)
# sample_means = np.zeros((N,tries))
sample_mean_average = np.zeros(N)
sample_mean_std = np.zeros(N)

ymin = 171
ymax = 180

plt.figure(figsize=(21,9))
plt.xticks(fontsize=font_size_ticks) 
plt.yticks(fontsize=font_size_ticks)
plt.ylim(ymin,ymax)
plt.xlim(0,n_max)
for ind_n,n in enumerate(n_vals):
    if n % 500 == 0:
        print(n)
    sample_means = np.zeros(tries)
    for ind_tries in range(tries):
        samples = rng.choice(stature,n,replace=True)
        #sample_means[ind_n,ind_tries] = np.mean(samples)
        sample_means[ind_tries] = np.mean(samples)
    plt.plot(n * np.ones(tries),sample_means,'.',color="silver",rasterized=True)
    sample_mean_average[ind_n] = np.mean(sample_means)
    sample_mean_std[ind_n] = np.std(sample_means) 
plt.plot(n_vals,population_mean + population_std/np.sqrt(n_vals),lw=2,ls='dashed',color='black',
         label=r"$\mu_{pop}+\frac{\sigma_{pop}}{\sqrt{n}}$")
plt.plot(n_vals,np.ones(len(n_vals))*population_mean,lw=2,color='black',
         label=r"$\mu_{pop}$")
plt.plot(n_vals,population_mean - population_std/np.sqrt(n_vals),lw=2,ls='dashed',color='black',
         label=r"$\mu_{pop}-\frac{\sigma_{pop}}{\sqrt{n}}$")
plt.xlabel(r"$n$",fontsize=font_size)
plt.ylabel(r'Sample mean of height (cms)',fontsize=font_size,labelpad=20)
plt.legend(fontsize=font_size)

plt.savefig('plots/height_sample_mean_n.pdf',bbox_inches="tight")
# Out:
# 500

# %%
tries = 20#int(1e2)
n_max_exp = 4
n_num = 100
n_vals = np.round(np.logspace(1,5,num=n_num)).astype(int)# np.arange(1,n_max,1))
n_max = 10**n_max_exp
# sample_means = np.zeros((N,tries))
sample_mean_average = np.zeros(N)
sample_mean_std = np.zeros(N)
eps = 0.25

ymin = 171.5
ymax = 179.5

plt.figure(figsize=(21,9))
plt.xticks(fontsize=font_size_ticks) 
plt.yticks(fontsize=font_size_ticks)
plt.ylim(ymin,ymax)
plt.xlim(10,n_max)
for ind_n,n in enumerate(n_vals):
    if n % 500 == 0:
        print(n)
    sample_means = np.zeros(tries)
    for ind_tries in range(tries):
        samples = rng.choice(stature,n,replace=True)
        #sample_means[ind_n,ind_tries] = np.mean(samples)
        sample_means[ind_tries] = np.mean(samples)
    plt.semilogx(n * np.ones(tries),sample_means,'.',markersize=15,color="gray",rasterized=True)
    sample_mean_average[ind_n] = np.mean(sample_means)
    sample_mean_std[ind_n] = np.std(sample_means) 
plt.semilogx(n_vals,np.ones(len(n_vals))*(population_mean+eps),lw=4,ls='dashed',color='black',
         label=r"$\mu_{pop}+\epsilon$")
#plt.semilogx(n_vals,np.ones(len(n_vals))*population_mean,lw=2,color='black',
#         label=r"$\mu_{pop}$")
plt.semilogx(n_vals,np.ones(len(n_vals))*(population_mean-eps),lw=4,ls='dashed',color='black',
         label=r"$\mu_{pop}-\epsilon$")
plt.xlabel(r"$n$",fontsize=font_size)
plt.ylabel(r'Sample mean of height (cms)',fontsize=font_size,labelpad=20)
plt.legend(fontsize=font_size)

plt.savefig('plots/height_lln.pdf',bbox_inches="tight")
# Out:
# 100000

# %%
epsilon = 1
tries = int(1e6)
n_vals = np.logspace(np.log10(15),np.log10(700),5).astype(int) # np.array([15,30,100,300,700]) # np.logspace(1,3,5).astype(int) #np.array([10,50,100,500,1000])
print(n_vals)
probs = np.zeros(len(n_vals))
for ind_n,n in enumerate(n_vals):
    count_epsilon = 0.0
    for ind_tries in range(tries):
        samples = rng.choice(stature,n,replace=True)
        sample_mean = np.mean(samples)
        if np.abs(sample_mean-population_mean) > epsilon:
            count_epsilon+=1
    print(count_epsilon)
    probs[ind_n] = count_epsilon / tries
# Out:
# [ 15  39 102 267 700]
# 572261.0
# 361309.0
# 140875.0
# 17072.0
# 133.0

# %%
n_vals = np.logspace(np.log10(15),np.log10(700),5).astype(int)
n_plot = np.logspace(1,3)
chebyshev_bound = population_std**2/(epsilon**2)/n_plot
clt_bound = np.zeros(len(n_plot))
for ind_n,n in enumerate(n_plot):
    epsilon_standardized = epsilon * np.sqrt(n) / population_std
    clt_bound[ind_n] = 2*(1-norm.cdf(epsilon_standardized,0,1))
    
plt.figure(figsize=(15,9))
plt.xticks(fontsize=font_size_ticks) 
plt.yticks(fontsize=font_size_ticks)
plt.loglog(n_plot,chebyshev_bound,lw=3,ls='dashed',color='black',label="Chebyshev bound")
plt.loglog(n_plot,clt_bound,lw=2,ls='solid',color='black',label="Central limit theorem")
plt.loglog(n_vals,probs,'o',markersize=15,markerfacecolor='white',markeredgecolor="black",markeredgewidth=2,
           label="Empirical probability")
plt.legend(fontsize=font_size)
plt.xlabel(r"$n$",fontsize=font_size)
plt.ylabel(r'P($|\widetilde{m}_n-\mu_{pop}|>1$ cm)',fontsize=font_size,labelpad=20)
plt.savefig('plots/height_lln_clt_bounds.pdf',bbox_inches="tight")

plt.figure(figsize=(15,9))
plt.xticks(fontsize=font_size_ticks) 
plt.yticks(fontsize=font_size_ticks)
plt.loglog(n_plot,chebyshev_bound,lw=3,ls='dashed',color='black',label="Chebyshev bound")
# plt.loglog(n_plot,clt_bound,lw=2,ls='solid',color='black',label="Central limit theorem")
plt.loglog(n_vals,probs,'o',markersize=15,markerfacecolor='white',markeredgecolor="black",markeredgewidth=2,
           label="Empirical probability")
plt.legend(fontsize=font_size)
plt.xlabel(r"$n$",fontsize=font_size)
plt.ylabel(r'P($|\widetilde{m}_n-\mu_{pop}|>1$ cm)',fontsize=font_size,labelpad=20)
plt.savefig('plots/height_lln_bounds.pdf',bbox_inches="tight")

# %%
print(font_size)
tries = int(1e4)
n_vals = [20,100,400,1000]
n_bins = 20
x = np.arange(-4,4+1e-2,1e-2)
x_min = 171
x_max = 180
y_max = 1.9
x_min_norm = -4.1
x_max_norm = 4.1

for ind_n,n in enumerate(n_vals):
    sample_means = np.zeros(tries)
    for ind_tries in range(tries):
        samples = rng.choice(stature,n,replace=True)
        #sample_means[ind_n,ind_tries] = np.mean(samples)
        sample_means[ind_tries] = np.mean(samples)
    sample_mean_average[ind_n] = np.mean(sample_means)
    sample_mean_std[ind_n] = np.std(sample_means)  
    plt.figure(figsize=(9,9))
    plt.xticks([172,174,175.6,177,179],fontsize=font_size_ticks) 
    plt.yticks(fontsize=font_size_ticks)
    plt.hist(sample_means,bins=n_bins,color='lightgray', edgecolor='black',
              linewidth=2,density=True)
    plt.ylim([0,y_max])
    plt.xlim([x_min,x_max])
    plt.ylabel(r"Probability density of sample mean",fontsize=font_size,labelpad=20)
    plt.xlabel('Height in cms',fontsize=font_size,labelpad=20)
    plt.savefig('plots/height_lln_'+str(n) +'.pdf',bbox_inches="tight")
    
    plt.figure(figsize=(9,9))
    plt.xticks(fontsize=font_size_ticks) 
    plt.yticks(fontsize=font_size_ticks)
    plt.hist((sample_means-population_mean)/(population_std / np.sqrt(n)),bins=n_bins,color='lightgray', edgecolor='black',
              linewidth=2,density=True)
    plt.plot(x,norm.pdf(x,0,1),lw=2.5,color="black",label='CLT approximation')
    plt.ylabel(r"Density of standardized sample mean",fontsize=font_size,labelpad=20)
    # plt.xlabel('Height in cms',fontsize=font_size,labelpad=20)
    plt.legend(fontsize=font_size,loc='upper left')
    plt.ylim([0,0.48])
    plt.xlim([x_min_norm,x_max_norm])
    plt.savefig('plots/height_clt_'+str(n) +'.pdf',bbox_inches="tight")
    #plt.savefig('plots/histogram_stature' + str(n) + '_norm.pdf',bbox_inches="tight")
# Out:
# 30

# %%
n = 100
samples = rng.choice(stature,n,replace=True)
sample_mean = 176#np.mean(samples)
sample_std = 7 #np.std(samples)
Phi_inv = 1.95 # Inverse cdf of 1-0.05/2
half_width = sample_std * Phi_inv / np.sqrt(n)
l = sample_mean - half_width
u = sample_mean + half_width
print("Sample mean: " + str(sample_mean))
print("Sample standard deviation: " + str(sample_std))
print("l: " + str(l))
print("u: " + str(u))
# Out:
# Sample mean: 176
# Sample standard deviation: 7
# l: 174.635
# u: 177.365

# %%
tries = 40
n_vals = [20,100,1000]
ymin = 168
ymax = 184
for n in n_vals:
    plt.figure(figsize=(25,9))
    plt.xticks([]) 
    plt.yticks([170,172,174,175.6,178,180,182],fontsize=font_size_ticks)
    plt.hlines(population_mean, -1,tries,lw=2,ls="dashed",color="black")
    plt.ylim(ymin,ymax)
    plt.xlim(-1,tries)
    for ind in range(tries):
        samples = rng.choice(stature,n,replace=True)
        sample_mean = np.mean(samples)
        sample_std = np.std(samples)
        Phi_inv = 1.95 # Inverse cdf of 1-0.05/2
        half_width = sample_std * Phi_inv / np.sqrt(n)
        l = sample_mean - half_width
        u = sample_mean + half_width
        plt.vlines(ind,l,u,lw=5,color="black")
    plt.savefig('plots/height_confidence_intervals_'+str(n) +'.pdf',bbox_inches="tight")

# %%
tries = 40
n_vals = [20,500]
ymin = 168
ymax = 184
for n in n_vals:
    plt.figure(figsize=(21,9))
    plt.xticks([]) 
    plt.yticks([175.6],[r"$\mu$"],fontsize=font_size_ticks)
    plt.hlines(population_mean, -1,tries,lw=1,ls="dashed",color="black")
    plt.ylim(ymin,ymax)
    plt.xlim(-1,tries)
    for ind in range(tries):
        samples = rng.choice(stature,n,replace=True)
        sample_mean = np.mean(samples)
        sample_std = np.std(samples)
        Phi_inv = 1.645 # Inverse cdf of 1-0.1/2
        half_width = sample_std * Phi_inv / np.sqrt(n)
        l = sample_mean - half_width
        u = sample_mean + half_width
        plt.vlines(ind,l,u,lw=3,color="black")
    plt.savefig('plots/confidence_intervals_exam_'+str(n) +'.pdf',bbox_inches="tight")
