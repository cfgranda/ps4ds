# %%
import matplotlib.pyplot as plt
import numpy as np
from os import listdir
import seaborn as sns
from scipy import stats
from numpy import linalg as LA
from numpy.random import default_rng
import matplotlib
matplotlib.rcParams['text.usetex'] = True

font_size = 30
font_size_ticks = 30

np.set_printoptions(precision=5)

def process_name(x):
    x = x[14:]
    x = x[:-7]
    x = x.translate(str.maketrans('','','_1234567890'))
    return x[2:] + ", " + x[:2]

str_path = "../data/weather/"

file_name_precipitation_2015 = str_path + "precipitation_2015.npy"
file_name_precipitation_2016 = str_path + "precipitation_2016.npy"

precipitation_matrix_2015 = np.load(file_name_precipitation_2015)
precipitation_matrix_2016 = np.load(file_name_precipitation_2016)

file_name_list = listdir(str_path + "hourly/2015/")
file_name_list.sort()

for ind,name in enumerate(file_name_list):
    print(ind)
    print(name)
# Out:
# 0
# CRNH0203-2015-AL_Brewton_3_NNE.txt
# 1
# CRNH0203-2015-AL_Clanton_2_NE.txt
# 2
# CRNH0203-2015-AL_Courtland_2_WSW.txt
# 3
# CRNH0203-2015-AL_Cullman_3_ENE.txt
# 4
# CRNH0203-2015-AL_Fairhope_3_NE.txt
# 5
# CRNH0203-2015-AL_Gadsden_19_N.txt
# 6
# CRNH0203-2015-AL_Gainesville_2_NE.txt
# 7
# CRNH0203-2015-AL_Greensboro_2_WNW.txt
# 8
# CRNH0203-2015-AL_Highland_Home_2_S.txt
# 9
# CRNH0203-2015-AL_Muscle_Shoals_2_N.txt
# 10
# CRNH0203-2015-AL_Northport_2_S.txt
# 11
# CRNH0203-2015-AL_Russellville_4_SSE.txt
# 12
# CRNH0203-2015-AL_Scottsboro_2_NE.txt
# 13
# CRNH0203-2015-AL_Selma_13_WNW.txt
# 14
# CRNH0203-2015-AL_Selma_6_SSE.txt
# 15
# CRNH0203-2015-AL_Talladega_10_NNE.txt
# 16
# CRNH0203-2015-AL_Thomasville_2_S.txt
# 17
# CRNH0203-2015-AL_Troy_2_W.txt
# 18
# CRNH0203-2015-AL_Valley_Head_1_SSW.txt
# 19
# CRNH0203-2015-AR_Batesville_8_WNW.txt
# 20
# CRNH0203-2015-AZ_Elgin_5_S.txt
# 21
# CRNH0203-2015-AZ_Tucson_11_W.txt
# 22
# CRNH0203-2015-AZ_Williams_35_NNW.txt
# 23
# ...

# %%
station = 99
print(process_name(file_name_list[station+1]))

def remove_faulty_measurements(data,verbose):
    min_val = -100 
    for ind in range(len(data)):
        median = np.median(data[data > min_val])
        if data[ind] < min_val:
            if verbose:
                print(str(ind) + ": " + str(data[ind]))
            aux_ind = ind-1
            while aux_ind > 0:
                if data[aux_ind] > min_val:
                    data[ind] = median
                    print("changed to entry " + str(aux_ind) + ": " + str(data[ind]))
                    break
                else:
                    ind -= 1
    return data

verbose = True
precipitation_aux_2015 = remove_faulty_measurements(precipitation_matrix_2015[:,station],verbose)
precipitation_2015 = np.zeros(len(precipitation_aux_2015))
precipitation_2015[precipitation_aux_2015 > 0] = 1
# Out:
# Corvallis, OR
# 3353: -9999.0
# changed to entry 3352: 0.0
# 4672: -9999.0
# changed to entry 4671: 0.0
# 4673: -9999.0
# changed to entry 4672: 0.0
# 4744: -9999.0
# changed to entry 4743: 0.0
# 6786: -9999.0
# changed to entry 6785: 0.0
# 6787: -9999.0
# changed to entry 6786: 0.0

# %%
p_precipitation = np.sum(precipitation_2015) / len(precipitation_2015)
print("Probability of precipitation in 2015: "+str(p_precipitation))
# Out:
# Probability of precipitation in 2015: 0.11335616438356165

# %%
n = 500
total = len(precipitation_2015)
n_samples = int(total/n)
x_min = -1
x_max = n_samples
y_min = -0.06
y_max = 0.59

plt.figure(figsize=(12,12))
plt.xticks([])
#plt.xticks(range(n_samples),prob_gold_sl.keys(),fontsize=font_size_ticks)#, rotation='vertical') 
plt.yticks(fontsize=font_size_ticks) 
plt.xlim(x_min,x_max)
plt.ylim(y_min,y_max)
plt.ylabel(r"Estimated probability",fontsize=font_size,labelpad=20)
plt.hlines(p_precipitation,x_min,x_max,lw=5,ls="dashed",color="gray",label="True probability")
for ind in range(n_samples):
    samples = precipitation_2015[ind*n:(ind+1)*n]
    estimated_p = np.sum(samples)/n
    sample_std = 0.5
    Phi_inv = 1.95 # Inverse cdf of 1-0.05/2
    half_width = sample_std * Phi_inv / np.sqrt(n)
    l = estimated_p - half_width
    u = estimated_p + half_width
    plt.vlines(ind,l,u,lw=10,color="black")
    # plt.grid(True)
    plt.plot(ind,estimated_p,"o",markersize=20,markeredgewidth=3,markerfacecolor = "white",markeredgecolor = "black")
plt.legend(fontsize=font_size,loc="upper left")
plt.savefig('plots/precipitation_confidence_intervals_contiguous.pdf',bbox_inches="tight")

# %%
rng = default_rng(2021)

plt.figure(figsize=(12,12))
#plt.xticks(range(n_samples),prob_gold_sl.keys(),fontsize=font_size_ticks)#, rotation='vertical') 
plt.yticks(fontsize=font_size_ticks) 
plt.xlim(x_min,x_max)
plt.ylim(y_min,y_max)
plt.ylabel(r"Estimated probability",fontsize=font_size,labelpad=20)
plt.hlines(p_precipitation,x_min,x_max,lw=5,ls="dashed",color="gray",label="True probability")
for ind in range(n_samples):
    samples = rng.choice(precipitation_2015,n,replace=True)
    estimated_p = np.sum(samples)/n
    sample_std = 0.5
    Phi_inv = 1.95 # Inverse cdf of 1-0.05/2
    half_width = sample_std * Phi_inv / np.sqrt(n)
    l = estimated_p - half_width
    u = estimated_p + half_width
    plt.vlines(ind,l,u,lw=10,color="black")
    # plt.grid(True)
    plt.plot(ind,estimated_p,"o",markersize=20,markeredgewidth=3,markerfacecolor = "white",markeredgecolor = "black")
plt.legend(fontsize=font_size,loc="upper left")
plt.savefig('plots/precipitation_confidence_intervals_random.pdf',bbox_inches="tight")
