# %% [markdown]
# [Probability and Statistics for Data Science](https://www.ps4ds.net/)
#
# Code for Example 9.27
#
# The Gambler's paradox shows that the law of large numbers can completely fail to hold if the underlying assumptions do not hold. Specifically, the sample mean of a sequence of i.i.d. random variables can diverge to infinity if their mean is not finite\
# Topics: Law of large numbers, sample mean
#
# Author: Carlos Fernandez-Granda

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
from scipy import stats
from scipy.stats import norm
from numpy.random import default_rng
rng = default_rng(2021)

font_size = 15
font_size_legend = 15
font_size_ticks = 15

# %%
tries = int(1e2)
n_vals = np.logspace(1,4,m,dtype=int)
n_max = 10**4

plt.figure(figsize=(10,4))
plt.xticks(fontsize=font_size_ticks) 
plt.yticks(fontsize=font_size_ticks)
plt.xlim([10,n_max])
for ind_n,n in enumerate(n_vals):
    # Coin flips (geometric distribution with parameter 0.5)
    realizations_aux = rng.geometric(0.5,(n,tries)).astype('float')
    # Winnings 
    realizations = 2**realizations_aux
    # Sample mean of the winnings
    sample_means = np.sum(realizations,axis=0) / n
    plt.loglog(n * np.ones(tries),sample_means,'.',ms=2,color="black")
plt.xlabel("n",fontsize=font_size)
plt.ylabel('Sample mean',fontsize=font_size,labelpad=20)
# Out:
# Text(0, 0.5, 'Sample mean')
