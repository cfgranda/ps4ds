# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import numpy.random.multinomial
matplotlib.rcParams['text.usetex'] = True

font_size = 30
font_size_ticks = 25

n = 60
true_pmf = [1/6.]*6
n_plots = 3

for ind in n_plots:
    counts = multinomial(n,true_pmf)
    print(counts)
    empirical_pmf = counts./n
    bin_edges = np.arange(0.5, 6.5+1, 1)
    plt.figure(figsize=(9,6))
    plt.bar(vals,histogram, width = 0.5, color = "lightgray", edgecolor="black",linewidth = 2)
    plt.xticks(np.arange(1, 6+1, 1))
    plt.xticks(fontsize=font_size_ticks) 
    plt.yticks(fontsize=font_size_ticks)
    plt.ylabel(r"$p_{X}(a)$",fontsize=font_size,labelpad = 30)
    plt.xlabel("Die roll values",fontsize=font_size)
    plt.savefig('plots/fair_die_empirical_pmf_'+str(ind)+'.pdf',bbox_inches="tight")

plt.figure(figsize=(9,6))
plt.bar(vals,pmf, width = 0.5, color = "lightgray", edgecolor="black",linewidth = 2)
plt.xticks(np.arange(1, 6+1, 1))
plt.xticks(fontsize=font_size_ticks) 
plt.yticks(fontsize=font_size_ticks)
plt.ylabel(r"$p_{X}(a)$",fontsize=font_size,labelpad = 10)
plt.xlabel(r'$a$',fontsize=font_size)
plt.savefig('plots/die_empirical_pmf.pdf',bbox_inches="tight")
