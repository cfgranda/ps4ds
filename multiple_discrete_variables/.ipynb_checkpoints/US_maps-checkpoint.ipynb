# %%
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import cartopy
import numpy as np

font_size = 20

fig = plt.figure(figsize=(12, 6))
#ax = plt.axes(projection=ccrs.Mercator(central_lon, central_lat))

ax = fig.add_axes([0, 0, 1, 1], projection=ccrs.LambertConformal())
ax.set_extent([-125, -66.5, 20, 50], ccrs.Geodetic())

# ax.set_extent(extent)
#ax.gridlines()
ax.coastlines(resolution='50m')
ax.plot(-117.1625, 32.715, 'o', markersize=7,color="black", transform=ccrs.Geodetic())
ax.text(-117, 33, 'San Diego', transform=ccrs.Geodetic(),fontsize=font_size)
#ax.add_feature(cartopy.feature.OCEAN)
#ax.add_feature(cartopy.feature.LAND, edgecolor='black')
#ax.add_feature(cartopy.feature.LAKES, edgecolor='black')
#ax.add_feature(cartopy.feature.RIVERS)
#ax.gridlines()
# Out:
# Text(-117, 33, 'San Diego')

# %%
fig = plt.figure(figsize=(12, 6))
#ax = plt.axes(projection=ccrs.Mercator(central_lon, central_lat))

ax = fig.add_axes([0, 0, 1, 1], projection=ccrs.LambertConformal())
ax.set_extent([-125, -66.5, 20, 50], ccrs.Geodetic())

# ax.set_extent(extent)
#ax.gridlines()
ax.coastlines(resolution='50m')
ax.plot(-117.1625, 32.715, 'o', markersize=7,color="black", transform=ccrs.Geodetic())
ax.text(-117, 33, 'San Diego', transform=ccrs.Geodetic(),fontsize=font_size)
#ax.add_feature(cartopy.feature.OCEAN)
#ax.add_feature(cartopy.feature.LAND, edgecolor='black')
#ax.add_feature(cartopy.feature.LAKES, edgecolor='black')
#ax.add_feature(cartopy.feature.RIVERS)
#ax.gridlines()
