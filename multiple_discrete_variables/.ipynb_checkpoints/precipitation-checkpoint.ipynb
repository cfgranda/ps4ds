# %%
import matplotlib.pyplot as plt
import numpy as np
from os import listdir

font_size = 20
font_size_ticks = 15

np.set_printoptions(precision=5)

def create_data_matrix(str_path):
    file_name_list = listdir(str_path)
    file_name_list.sort()
    col_ind = 12
    data_matrix = []
    ind = 0
    for file_name in file_name_list:
        if file_name[0] == '.':
            continue
        else:
            print("Station " + str(ind))
            print(file_name)
            ind = ind + 1
            #data_aux = extract_temp(str_path + file_name,col_ind)
            data_aux = np.loadtxt(str_path + file_name, usecols=range(14))
            data = data_aux[:,col_ind]
            if len(data_matrix) == 0:
                data_matrix = data
            else:
                data_matrix = np.vstack((data_matrix,data))
    return data_matrix.T

def process_name(x):
    x = x[14:]
    x = x[:-7]
    x = x.translate(str.maketrans('','','_1234567890'))
    return x[2:] + ", " + x[:2]

str_path = "./data/weather/"

load_files = True
str_path_2015 = str_path + "hourly/2015/"
file_name_2015 = str_path + "precipitation_2015.npy"
str_path_2016 = str_path + "hourly/2016/"
file_name_2016 = str_path + "precipitation_2016.npy"

if load_files:
    data_matrix_2015 = create_data_matrix(str_path_2015)
    data_matrix_2016 = create_data_matrix(str_path_2016)
    np.save(file_name_2015,data_matrix_2015)
    np.save(file_name_2016,data_matrix_2016)
else:
    data_matrix_2015 = np.load(file_name_2015)
    data_matrix_2016 = np.load(file_name_2016)

file_name_list = listdir(str_path + "hourly/2015/")
file_name_list.sort()

for ind,name in enumerate(file_name_list):
    print(ind)
    print(name)

print(data_matrix_2015.shape)
print(data_matrix_2015[25:35,:10])
# Out:
# Station 0
# CRNH0203-2015-AL_Brewton_3_NNE.txt
# Station 1
# CRNH0203-2015-AL_Clanton_2_NE.txt
# Station 2
# CRNH0203-2015-AL_Courtland_2_WSW.txt
# Station 3
# CRNH0203-2015-AL_Cullman_3_ENE.txt
# Station 4
# CRNH0203-2015-AL_Fairhope_3_NE.txt
# Station 5
# CRNH0203-2015-AL_Gadsden_19_N.txt
# Station 6
# CRNH0203-2015-AL_Gainesville_2_NE.txt
# Station 7
# CRNH0203-2015-AL_Greensboro_2_WNW.txt
# Station 8
# CRNH0203-2015-AL_Highland_Home_2_S.txt
# Station 9
# CRNH0203-2015-AL_Muscle_Shoals_2_N.txt
# Station 10
# CRNH0203-2015-AL_Northport_2_S.txt
# Station 11
# CRNH0203-2015-AL_Russellville_4_SSE.txt
# Station 12
# CRNH0203-2015-AL_Scottsboro_2_NE.txt
# Station 13
# CRNH0203-2015-AL_Selma_13_WNW.txt
# Station 14
# CRNH0203-2015-AL_Selma_6_SSE.txt
# Station 15
# CRNH0203-2015-AL_Talladega_10_NNE.txt
# Station 16
# CRNH0203-2015-AL_Thomasville_2_S.txt
# Station 17
# CRNH0203-2015-AL_Troy_2_W.txt
# Station 18
# CRNH0203-2015-AL_Valley_Head_1_SSW.txt
# Station 19
# ...

# %%
stations = [99,100,101]
for station in stations:
    print(process_name(file_name_list[station+1])) # list starts at 1
# Out:
# Corvallis, OR
# JohnDay, OR
# Riley, OR

# %%
def compute_joint_pmf(station_1,station_2,station_3,data_matrix):
    submatrix = data_matrix[:,[station_1,station_2,station_3]]
    total_count = 0.
    counts = np.zeros((2,2,2))
    for ind in range(submatrix.shape[0]):
        rain_1 = int(submatrix[ind,0] > 0.)
        rain_2 = int(submatrix[ind,1] > 0.)
        rain_3 = int(submatrix[ind,2] > 0.)
        total_count += 1
        counts[rain_1,rain_2,rain_3] += 1
    joint_pmf = counts/total_count
    return counts,joint_pmf

counts,joint_pmf = compute_joint_pmf(stations[0],stations[1],stations[2],data_matrix_2015)
print(counts)
print(joint_pmf)
# Out:
# [[[7253.  162.]
#   [ 318.   34.]]
#
#  [[ 462.   30.]
#   [ 432.   69.]]]
# [[[0.82797 0.01849]
#   [0.0363  0.00388]]
#
#  [[0.05274 0.00342]
#   [0.04932 0.00788]]]

# %%
def marginal_1_station(joint_pmf):
    marginal_pmf_1 = np.zeros(2)
    for ind_2 in range(2):
        for ind_3 in range(2):
            marginal_pmf_1 += joint_pmf[:,ind_2,ind_3]
    marginal_pmf_2 = np.zeros(2)
    for ind_1 in range(2):
        for ind_3 in range(2):
            marginal_pmf_2 += joint_pmf[ind_1,:,ind_3]
    marginal_pmf_3 = np.zeros(2)
    for ind_1 in range(2):
        for ind_2 in range(2):
            marginal_pmf_3 += joint_pmf[ind_1,ind_2,:]
    return marginal_pmf_1,marginal_pmf_2,marginal_pmf_3

marginal_pmf_1,marginal_pmf_2,marginal_pmf_3 = marginal_1_station(joint_pmf)
print(process_name(file_name_list[stations[0]+1]))
print(marginal_pmf_1)
print(process_name(file_name_list[stations[1]+1]))
print(marginal_pmf_2)
print(process_name(file_name_list[stations[2]+1]))
print(marginal_pmf_3)

vals = [0,1]
ymax = 1.0
xmin = -0.6
xmax = 1.6
plt.figure(figsize=(6,9))
plt.bar(vals,marginal_pmf_1, width = 0.5, color = "lightgray", edgecolor="black",linewidth = 2)
plt.xticks(np.arange(0, 1+1, 1))
plt.xticks(fontsize=font_size_ticks) 
plt.yticks(fontsize=font_size_ticks)
plt.ylim([0,ymax])
plt.xlim([xmin,xmax])
plt.ylabel("Probability mass function",fontsize=font_size,labelpad = 30)
plt.xlabel("Precipitation",fontsize=font_size,labelpad = 15)
plt.savefig('plots/precipitation_marginal_pmf_1.pdf',bbox_inches="tight")

plt.figure(figsize=(6,9))
plt.bar(vals,marginal_pmf_2, width = 0.5, color = "lightgray", edgecolor="black",linewidth = 2)
plt.xticks(np.arange(0, 1+1, 1))
plt.xticks(fontsize=font_size_ticks) 
plt.yticks(fontsize=font_size_ticks)
plt.ylim([0,ymax])
plt.xlim([xmin,xmax])
plt.ylabel("Probability mass function",fontsize=font_size,labelpad = 30)
plt.xlabel("Precipitation",fontsize=font_size,labelpad = 15)
plt.savefig('plots/precipitation_marginal_pmf_2.pdf',bbox_inches="tight")

plt.figure(figsize=(6,9))
plt.bar(vals,marginal_pmf_3, width = 0.5, color = "lightgray", edgecolor="black",linewidth = 2)
plt.xticks(np.arange(0, 1+1, 1))
plt.xticks(fontsize=font_size_ticks) 
plt.yticks(fontsize=font_size_ticks)
plt.ylim([0,ymax])
plt.xlim([xmin,xmax])
plt.ylabel("Probability mass function",fontsize=font_size,labelpad = 30)
plt.xlabel("Precipitation",fontsize=font_size,labelpad = 15)
plt.savefig('plots/precipitation_marginal_pmf_3.pdf',bbox_inches="tight")
# Out:
# Corvallis, OR
# [0.88664 0.11336]
# JohnDay, OR
# [0.90263 0.09737]
# Riley, OR
# [0.96632 0.03368]

# %%
def marginal_2_stations(joint_pmf):
    marginal_pmf_12 = np.zeros((2,2))
    for ind_3 in range(2):
        marginal_pmf_12 += joint_pmf[:,:,ind_3]
    marginal_pmf_13 = np.zeros((2,2))
    for ind_2 in range(2):
        marginal_pmf_13 += joint_pmf[:,ind_2,:]
    marginal_pmf_23 = np.zeros((2,2))
    for ind_1 in range(2):
        marginal_pmf_23 += joint_pmf[ind_1,:,:]
    return marginal_pmf_12,marginal_pmf_13,marginal_pmf_23

marginal_pmf_12,marginal_pmf_13,marginal_pmf_23 = marginal_2_stations(joint_pmf)

print(process_name(file_name_list[stations[0]+1]) + " and " + process_name(file_name_list[stations[1]+1]))
print(marginal_pmf_12)

print(process_name(file_name_list[stations[0]+1]) + " and " + process_name(file_name_list[stations[2]+1]))
print(marginal_pmf_13)

print(process_name(file_name_list[stations[1]+1]) + " and " + process_name(file_name_list[stations[2]+1]))
print(marginal_pmf_23)
# Out:
# Corvallis, OR and JohnDay, OR
# [[0.84646 0.04018]
#  [0.05616 0.05719]]
# Corvallis, OR and Riley, OR
# [[0.86427 0.02237]
#  [0.10205 0.0113 ]]
# JohnDay, OR and Riley, OR
# [[0.88071 0.02192]
#  [0.08562 0.01176]]

# %%
def conditional_1_station_given_2(joint_pmf):
    cond_1_given_23 = np.zeros((2,2,2))
    for ind_2 in range(2):
        for ind_3 in range(2):
            cond_1_given_23[ind_2][ind_3] = joint_pmf[:,ind_2,ind_3] / np.sum(joint_pmf[:,ind_2,ind_3])
    cond_2_given_13 = np.zeros((2,2,2))
    for ind_1 in range(2):
        for ind_3 in range(2):
            cond_2_given_13[ind_1][ind_3] = joint_pmf[ind_1,:,ind_3] / np.sum(joint_pmf[ind_1,:,ind_3])
    cond_3_given_12 = np.zeros((2,2,2))
    for ind_1 in range(2):
        for ind_2 in range(2):
            cond_3_given_12[ind_1][ind_2] = joint_pmf[ind_1,ind_2,:] / np.sum(joint_pmf[ind_1,ind_2,:])        
    return cond_1_given_23,cond_2_given_13,cond_3_given_12

cond_1_given_23,cond_2_given_13,cond_3_given_12 = conditional_1_station_given_2(joint_pmf)

for ind_2 in range(2):
    for ind_3 in range(2):
        print(process_name(file_name_list[stations[0]+1]) + " conditioned on " + process_name(file_name_list[stations[1]+1])
             + " = " + str(ind_2) + " and " + process_name(file_name_list[stations[2]+1])
             + " = " + str(ind_3))
        print(cond_1_given_23[ind_2][ind_3])
        plt.figure(figsize=(6,9))
        plt.bar(vals,cond_1_given_23[ind_2][ind_3], width = 0.5, color = "lightgray", edgecolor="black",linewidth = 2)
        plt.xticks(np.arange(0, 1+1, 1))
        plt.xticks(fontsize=font_size_ticks) 
        plt.yticks(fontsize=font_size_ticks)
        plt.ylim([0,ymax])
        plt.xlim([xmin,xmax])
        plt.ylabel("Conditional pmf",fontsize=font_size,labelpad = 30)
        plt.xlabel("Precipitation",fontsize=font_size,labelpad = 15)
        plt.savefig('plots/precipitation_cond_pmf_1_given_2eq'+str(ind_2)+'_3eq'+str(ind_3)+'.pdf',bbox_inches="tight")

for ind_1 in range(2):
    for ind_3 in range(2):
        print(process_name(file_name_list[stations[1]+1]) + " conditioned on " + process_name(file_name_list[stations[0]+1])
             + " = " + str(ind_1) + " and " + process_name(file_name_list[stations[2]+1])
             + " = " + str(ind_3))
        print(cond_2_given_13[ind_1][ind_3])
        plt.figure(figsize=(6,9))
        plt.bar(vals,cond_2_given_13[ind_1][ind_3], width = 0.5, color = "lightgray", edgecolor="black",linewidth = 2)
        plt.xticks(np.arange(0, 1+1, 1))
        plt.xticks(fontsize=font_size_ticks) 
        plt.yticks(fontsize=font_size_ticks)
        plt.ylim([0,ymax])
        plt.xlim([xmin,xmax])
        plt.ylabel("Conditional pmf",fontsize=font_size,labelpad = 30)
        plt.xlabel("Precipitation",fontsize=font_size,labelpad = 15)
        plt.savefig('plots/precipitation_cond_pmf_2_given_1eq'+str(ind_1)+'_3eq'+str(ind_3)+'.pdf',bbox_inches="tight")

for ind_1 in range(2):
    for ind_2 in range(2):
        print(process_name(file_name_list[stations[2]+1]) + " conditioned on " + process_name(file_name_list[stations[0]+1])
             + " = " + str(ind_1) + " and " + process_name(file_name_list[stations[1]+1])
             + " = " + str(ind_2))
        print(cond_3_given_12[ind_1][ind_2])
        plt.figure(figsize=(6,9))
        plt.bar(vals,cond_3_given_12[ind_1][ind_2], width = 0.5, color = "lightgray", edgecolor="black",linewidth = 2)
        plt.xticks(np.arange(0, 1+1, 1))
        plt.xticks(fontsize=font_size_ticks) 
        plt.yticks(fontsize=font_size_ticks)
        plt.ylim([0,ymax])
        plt.xlim([xmin,xmax])
        plt.ylabel("Conditional pmf",fontsize=font_size,labelpad = 30)
        plt.xlabel("Precipitation",fontsize=font_size,labelpad = 15)
        plt.savefig('plots/precipitation_cond_pmf_3_given_1eq'+str(ind_1)+'_2eq'+str(ind_2)+'.pdf',bbox_inches="tight")
# Out:
# Corvallis, OR conditioned on JohnDay, OR = 0 and Riley, OR = 0
# [0.94012 0.05988]
# Corvallis, OR conditioned on JohnDay, OR = 0 and Riley, OR = 1
# [0.84375 0.15625]
# Corvallis, OR conditioned on JohnDay, OR = 1 and Riley, OR = 0
# [0.424 0.576]
# Corvallis, OR conditioned on JohnDay, OR = 1 and Riley, OR = 1
# [0.3301 0.6699]
# JohnDay, OR conditioned on Corvallis, OR = 0 and Riley, OR = 0
# [0.958 0.042]
# JohnDay, OR conditioned on Corvallis, OR = 0 and Riley, OR = 1
# [0.82653 0.17347]
# JohnDay, OR conditioned on Corvallis, OR = 1 and Riley, OR = 0
# [0.51678 0.48322]
# JohnDay, OR conditioned on Corvallis, OR = 1 and Riley, OR = 1
# [0.30303 0.69697]
# Riley, OR conditioned on Corvallis, OR = 0 and JohnDay, OR = 0
# [0.97815 0.02185]
# Riley, OR conditioned on Corvallis, OR = 0 and JohnDay, OR = 1
# [0.90341 0.09659]
# Riley, OR conditioned on Corvallis, OR = 1 and JohnDay, OR = 0
# [0.93902 0.06098]
# Riley, OR conditioned on Corvallis, OR = 1 and JohnDay, OR = 1
# ...

# %%
def conditional_2_stations_given_1(joint_pmf):
    cond_12_given_3 = np.zeros((2,2,2))
    for ind in range(2):
        cond_12_given_3[ind] = joint_pmf[:,:,ind] / np.sum(joint_pmf[:,:,ind],axis=None)
    cond_13_given_2 = np.zeros((2,2,2))
    for ind in range(2):
        cond_13_given_2[ind] = joint_pmf[:,ind,:] / np.sum(joint_pmf[:,ind,:],axis=None)
    cond_23_given_1 = np.zeros((2,2,2))
    for ind in range(2):
        cond_23_given_1[ind] = joint_pmf[ind,:,:] / np.sum(joint_pmf[ind,:,:],axis=None)
    return cond_12_given_3,cond_13_given_2,cond_23_given_1

cond_12_given_3,cond_13_given_2,cond_23_given_1 = conditional_2_stations_given_1(joint_pmf)

for ind in range(2):
    print(process_name(file_name_list[stations[0]+1]) + " and " + process_name(file_name_list[stations[1]+1])
             + " conditioned on " + process_name(file_name_list[stations[2]+1]) + " = " + str(ind))
    print(cond_12_given_3[ind])
for ind in range(2):
    print(process_name(file_name_list[stations[0]+1]) + " and " + process_name(file_name_list[stations[2]+1])
             + " conditioned on " + process_name(file_name_list[stations[1]+1]) + " = " + str(ind))
    print(cond_13_given_2[ind])
for ind in range(2):
    print(process_name(file_name_list[stations[1]+1]) + " and " + process_name(file_name_list[stations[2]+1])
             + " conditioned on " + process_name(file_name_list[stations[0]+1]) + " = " + str(ind))
    print(cond_23_given_1[ind])
# Out:
# Corvallis, OR and JohnDay, OR conditioned on Riley, OR = 0
# [[0.85682 0.03757]
#  [0.05458 0.05103]]
# Corvallis, OR and JohnDay, OR conditioned on Riley, OR = 1
# [[0.54915 0.11525]
#  [0.10169 0.2339 ]]
# Corvallis, OR and Riley, OR conditioned on JohnDay, OR = 0
# [[0.91729 0.02049]
#  [0.05843 0.00379]]
# Corvallis, OR and Riley, OR conditioned on JohnDay, OR = 1
# [[0.3728  0.03986]
#  [0.50645 0.08089]]
# JohnDay, OR and Riley, OR conditioned on Corvallis, OR = 0
# [[0.93382 0.02086]
#  [0.04094 0.00438]]
# JohnDay, OR and Riley, OR conditioned on Corvallis, OR = 1
# [[0.46526 0.03021]
#  [0.43505 0.06949]]

# %%
def conditional_1_station_given_1_station(joint_pmf):
    marginal_pmf_12,marginal_pmf_13,marginal_pmf_23 = marginal_2_stations(joint_pmf)
    
    cond_1 = {}
    cond_1["2"]=np.zeros((2,2))
    cond_1["2"][0] = marginal_pmf_12[:,0]/np.sum(marginal_pmf_12[:,0])
    cond_1["2"][1] = marginal_pmf_12[:,1]/np.sum(marginal_pmf_12[:,1])
    cond_1["3"]=np.zeros((2,2))
    cond_1["3"][0] = marginal_pmf_13[:,0]/np.sum(marginal_pmf_13[:,0])
    cond_1["3"][1] = marginal_pmf_13[:,1]/np.sum(marginal_pmf_13[:,1])
    
    cond_2 = {}
    cond_2["1"]=np.zeros((2,2))
    cond_2["1"][0] = marginal_pmf_12[:,0]/np.sum(marginal_pmf_12[:,0])
    cond_2["1"][1] = marginal_pmf_12[:,1]/np.sum(marginal_pmf_12[:,1])
    cond_2["3"]=np.zeros((2,2))
    cond_2["3"][0] = marginal_pmf_23[0,:]/np.sum(marginal_pmf_23[0,:])
    cond_2["3"][1] = marginal_pmf_23[1,:]/np.sum(marginal_pmf_23[1,:])
    
    cond_3 = {}
    cond_3["1"]=np.zeros((2,2))
    cond_3["1"][0] = marginal_pmf_13[0,:]/np.sum(marginal_pmf_13[0,:])
    cond_3["1"][1] = marginal_pmf_13[1,:]/np.sum(marginal_pmf_13[1,:])
    cond_3["2"]=np.zeros((2,2))
    cond_3["2"][0] = marginal_pmf_23[0,:]/np.sum(marginal_pmf_23[0,:])
    cond_3["2"][1] = marginal_pmf_23[1,:]/np.sum(marginal_pmf_23[1,:])
    
    return cond_1,cond_2,cond_3

cond_1,cond_2,cond_3 = conditional_1_station_given_1_station(joint_pmf)

print('Coos Bay, conditional pmfs:')
print(cond_1)
for given in ["2","3"]:
    for ind in range(2):
        plt.figure(figsize=(6,9))
        plt.bar(vals,cond_1[given][ind], width = 0.5, color = "lightgray", edgecolor="black",linewidth = 2)
        plt.xticks(np.arange(0, 1+1, 1))
        plt.xticks(fontsize=font_size_ticks) 
        plt.yticks(fontsize=font_size_ticks)
        plt.ylim([0,ymax])
        plt.xlim([xmin,xmax])
        plt.ylabel("Conditional pmf",fontsize=font_size,labelpad = 30)
        plt.xlabel("Precipitation",fontsize=font_size,labelpad = 15)
        plt.savefig('plots/precipitation_cond_pmf_1_given_'+ given + 'eq'+str(ind)+'.pdf',bbox_inches="tight")
        
print('Corvallis, conditional pmfs:')
print(cond_2)
for given in ["1","3"]:
    for ind in range(2):
        plt.figure(figsize=(6,9))
        plt.bar(vals,cond_2[given][ind], width = 0.5, color = "lightgray", edgecolor="black",linewidth = 2)
        plt.xticks(np.arange(0, 1+1, 1))
        plt.xticks(fontsize=font_size_ticks) 
        plt.yticks(fontsize=font_size_ticks)
        plt.ylim([0,ymax])
        plt.xlim([xmin,xmax])
        plt.ylabel("Conditional pmf",fontsize=font_size,labelpad = 30)
        plt.xlabel("Precipitation",fontsize=font_size,labelpad = 15)
        plt.savefig('plots/precipitation_cond_pmf_2_given_'+ given + 'eq'+str(ind)+'.pdf',bbox_inches="tight")

print('John Day, conditional pmfs:')
print(cond_3)
for given in ["1","2"]:
    for ind in range(2):
        plt.figure(figsize=(6,9))
        plt.bar(vals,cond_3[given][ind], width = 0.5, color = "lightgray", edgecolor="black",linewidth = 2)
        plt.xticks(np.arange(0, 1+1, 1))
        plt.xticks(fontsize=font_size_ticks) 
        plt.yticks(fontsize=font_size_ticks)
        plt.ylim([0,ymax])
        plt.xlim([xmin,xmax])
        plt.ylabel("Conditional pmf",fontsize=font_size,labelpad = 30)
        plt.xlabel("Precipitation",fontsize=font_size,labelpad = 15)
        plt.savefig('plots/precipitation_cond_pmf_3_given_'+ given + 'eq'+str(ind)+'.pdf',bbox_inches="tight")
# Out:
# Coos Bay, conditional pmfs:
# {'2': array([[0.93778, 0.06222],
#        [0.41266, 0.58734]]), '3': array([[0.89439, 0.10561],
#        [0.66441, 0.33559]])}
# Corvallis, conditional pmfs:
# {'1': array([[0.93778, 0.06222],
#        [0.41266, 0.58734]]), '3': array([[0.97572, 0.02428],
#        [0.87925, 0.12075]])}
# John Day, conditional pmfs:
# {'1': array([[0.97477, 0.02523],
#        [0.9003 , 0.0997 ]]), '2': array([[0.97572, 0.02428],
#        [0.87925, 0.12075]])}

# %%
stations_indep = [44,105]
for station in stations_indep:
    print(process_name(file_name_list[station+1])) # list starts at 1
# Out:
# MaunaLoa, HI
# Tiksi, SA

# %%
def compute_joint_pmf_just2(station_1,station_2,data_matrix):
    submatrix = data_matrix[:,[station_1,station_2]]
    total_count = 0.
    counts = np.zeros((2,2))
    for ind in range(submatrix.shape[0]):
        rain_1 = int(submatrix[ind,0] > 0.)
        rain_2 = int(submatrix[ind,1] > 0.)
        total_count += 1
        counts[rain_1,rain_2] += 1
    joint_pmf = counts/total_count
    return counts,joint_pmf

counts_new,joint_pmf_indep = compute_joint_pmf_just2(stations_indep[0],stations_indep[1],data_matrix_2015)

print(counts)
print(joint_pmf_indep)
# Out:
# [[[7253.  162.]
#   [ 318.   34.]]
#
#  [[ 462.   30.]
#   [ 432.   69.]]]
# [[0.68539 0.05947]
#  [0.23368 0.02146]]

# %%
marginal_pmf_1 = np.sum(joint_pmf_indep,axis=1)
print("Marginal pmf of " + process_name(file_name_list[stations_indep[0]+1]))
print(marginal_pmf_1)

marginal_pmf_2 = np.sum(joint_pmf_indep,axis=0)
print("Marginal pmf of " + process_name(file_name_list[stations_indep[1]+1]))
print(marginal_pmf_2)

vals = [0,1]
ymax = 1.0
xmin = -0.6
xmax = 1.6

plt.figure(figsize=(6,9))
plt.bar(vals,marginal_pmf_1, width = 0.5, color = "lightgray", edgecolor="black",linewidth = 2)
plt.xticks(np.arange(0, 1+1, 1))
plt.xticks(fontsize=font_size_ticks) 
plt.yticks(fontsize=font_size_ticks)
plt.ylim([0,ymax])
plt.xlim([xmin,xmax])
plt.ylabel("Marginal pmf",fontsize=font_size,labelpad = 30)
plt.xlabel("Precipitation",fontsize=font_size,labelpad = 15)
plt.savefig('plots/precipitation_marginal_pmf_1_indep.pdf',bbox_inches="tight")

plt.figure(figsize=(6,9))
plt.bar(vals,marginal_pmf_2, width = 0.5, color = "lightgray", edgecolor="black",linewidth = 2)
plt.xticks(np.arange(0, 1+1, 1))
plt.xticks(fontsize=font_size_ticks) 
plt.yticks(fontsize=font_size_ticks)
plt.ylim([0,ymax])
plt.xlim([xmin,xmax])
plt.ylabel("Marginal pmf",fontsize=font_size,labelpad = 30)
plt.xlabel("Precipitation",fontsize=font_size,labelpad = 15)
plt.savefig('plots/precipitation_marginal_pmf_2_indep.pdf',bbox_inches="tight")
# Out:
# Marginal pmf of MaunaLoa, HI
# [0.74486 0.25514]
# Marginal pmf of Tiksi, SA
# [0.91906 0.08094]

# %%
cond_1=np.zeros((2,2))
cond_1[0] = joint_pmf_indep[:,0]/np.sum(joint_pmf_indep[:,0])
cond_1[1] = joint_pmf_indep[:,1]/np.sum(joint_pmf_indep[:,1])
cond_2=np.zeros((2,2))
cond_2[0] = joint_pmf_indep[0,:]/np.sum(joint_pmf_indep[0,:])
cond_2[1] = joint_pmf_indep[1,:]/np.sum(joint_pmf_indep[1,:])

for ind in range(2):
    plt.figure(figsize=(6,9))
    plt.bar(vals,cond_1[ind], width = 0.5, color = "lightgray", edgecolor="black",linewidth = 2)
    plt.xticks(np.arange(0, 1+1, 1))
    plt.xticks(fontsize=font_size_ticks) 
    plt.yticks(fontsize=font_size_ticks)
    plt.ylim([0,ymax])
    plt.xlim([xmin,xmax])
    plt.ylabel("Conditional pmf",fontsize=font_size,labelpad = 30)
    plt.xlabel("Precipitation",fontsize=font_size,labelpad = 15)
    plt.savefig('plots/precipitation_cond_pmf_1_given_2eq'+str(ind)+'_indep.pdf',bbox_inches="tight")
    print("Conditional pmf of " + process_name(file_name_list[stations_indep[0]+1]) + " given "
          + process_name(file_name_list[stations_indep[1]+1]) + " = " + str(ind))
    print(cond_1[ind])


for ind in range(2):
    plt.figure(figsize=(6,9))
    plt.bar(vals,cond_2[ind], width = 0.5, color = "lightgray", edgecolor="black",linewidth = 2)
    plt.xticks(np.arange(0, 1+1, 1))
    plt.xticks(fontsize=font_size_ticks) 
    plt.yticks(fontsize=font_size_ticks)
    plt.ylim([0,ymax])
    plt.xlim([xmin,xmax])
    plt.ylabel("Conditional pmf",fontsize=font_size,labelpad = 30)
    plt.xlabel("Precipitation",fontsize=font_size,labelpad = 15)
    plt.savefig('plots/precipitation_cond_pmf_2_given_1eq'+str(ind)+'_indep.pdf',bbox_inches="tight")
    print("Conditional pmf of " + process_name(file_name_list[stations_indep[1]+1]) + " given "
          + process_name(file_name_list[stations_indep[0]+1]) + " = " + str(ind))
    print(cond_2[ind])
# Out:
# Conditional pmf of MaunaLoa, HI given Tiksi, SA = 0
# [0.74575 0.25425]
# Conditional pmf of MaunaLoa, HI given Tiksi, SA = 1
# [0.73484 0.26516]
# Conditional pmf of Tiksi, SA given MaunaLoa, HI = 0
# [0.92015 0.07985]
# Conditional pmf of Tiksi, SA given MaunaLoa, HI = 1
# [0.91588 0.08412]

# %%
stations_cond_indep = [99,44,45]
for station in stations_cond_indep:
    print(process_name(file_name_list[station+1])) # list starts at 1
# Out:
# Corvallis, OR
# MaunaLoa, HI
# DesMoines, IA

# %%
counts,joint_pmf_cond_indep = compute_joint_pmf(stations_cond_indep[0],stations_cond_indep[1],stations_cond_indep[2],data_matrix_2015)
print(counts)
print(joint_pmf_cond_indep)
# Out:
# [[[5654.  170.]
#   [1807.  136.]]
#
#  [[ 701.    0.]
#   [ 286.    6.]]]
# [[[0.64543 0.01941]
#   [0.20628 0.01553]]
#
#  [[0.08002 0.     ]
#   [0.03265 0.00068]]]

# %%
cond_1_given_23,cond_2_given_13,cond_3_given_12 = conditional_1_station_given_2(joint_pmf_cond_indep)

for ind_2 in range(2):
    for ind_3 in range(2):
        print(process_name(file_name_list[stations_cond_indep[0]+1]) + " conditioned on " + process_name(file_name_list[stations_cond_indep[1]+1])
             + " = " + str(ind_2) + " and " + process_name(file_name_list[stations_cond_indep[2]+1])
             + " = " + str(ind_3))
        print(cond_1_given_23[ind_2][ind_3])
        plt.figure(figsize=(6,9))
        plt.bar(vals,cond_1_given_23[ind_2][ind_3], width = 0.5, color = "lightgray", edgecolor="black",linewidth = 2)
        plt.xticks(np.arange(0, 1+1, 1))
        plt.xticks(fontsize=font_size_ticks) 
        plt.yticks(fontsize=font_size_ticks)
        plt.ylim([0,ymax])
        plt.xlim([xmin,xmax])
        plt.ylabel("Conditional pmf",fontsize=font_size,labelpad = 30)
        plt.xlabel("Precipitation",fontsize=font_size,labelpad = 15)
        plt.savefig('plots/precipitation_cond_pmf_1_given_2eq'+str(ind_2)+'_3eq'+str(ind_3)+'_cond_indep.pdf',bbox_inches="tight")
# Out:
# Corvallis, OR conditioned on MaunaLoa, HI = 0 and DesMoines, IA = 0
# [0.88969 0.11031]
# Corvallis, OR conditioned on MaunaLoa, HI = 0 and DesMoines, IA = 1
# [1. 0.]
# Corvallis, OR conditioned on MaunaLoa, HI = 1 and DesMoines, IA = 0
# [0.86335 0.13665]
# Corvallis, OR conditioned on MaunaLoa, HI = 1 and DesMoines, IA = 1
# [0.95775 0.04225]

# %%
cond_1,cond_2,cond_3 = conditional_1_station_given_1_station(joint_pmf_cond_indep)

print(cond_1)

for given in ["2","3"]:
    for ind in range(2):
        plt.figure(figsize=(6,9))
        plt.bar(vals,cond_1[given][ind], width = 0.5, color = "lightgray", edgecolor="black",linewidth = 2)
        plt.xticks(np.arange(0, 1+1, 1))
        plt.xticks(fontsize=font_size_ticks) 
        plt.yticks(fontsize=font_size_ticks)
        plt.ylim([0,ymax])
        plt.xlim([xmin,xmax])
        plt.ylabel("Conditional pmf",fontsize=font_size,labelpad = 30)
        plt.xlabel("Precipitation",fontsize=font_size,labelpad = 15)
        plt.savefig('plots/precipitation_cond_pmf_1_given_'+ given + 'eq'+str(ind)+'_cond_indep.pdf',bbox_inches="tight")
# Out:
# {'2': array([[0.89257, 0.10743],
#        [0.86935, 0.13065]]), '3': array([[0.88317, 0.11683],
#        [0.98077, 0.01923]])}
