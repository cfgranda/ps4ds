# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
np.random.seed(2022)

font_size = 25
font_size_ticks = 22

rating_names = ['user_id', 'movie_id', 'rating', 'timestamp']
ratings = pd.read_csv('../data/ml-100k/u.data', sep='\t', encoding='latin-1',names=rating_names)
movie_names = ['movie_id', 'title', 'release_date']
movies = pd.read_csv('../data/ml-100k/u.item', sep='|', names=movie_names,usecols=range(3),
                     encoding='latin-1')
data = pd.merge(movies,ratings)
print(data.columns)
print(data.head(3))
print(data.title.value_counts()[:20])
print(data.user_id.value_counts()[:5])
print(data.rating.value_counts())
# Out:
# Index(['movie_id', 'title', 'release_date', 'user_id', 'rating', 'timestamp'], dtype='object')
#    movie_id             title release_date  user_id  rating  timestamp
# 0         1  Toy Story (1995)  01-Jan-1995      308       4  887736532
# 1         1  Toy Story (1995)  01-Jan-1995      287       5  875334088
# 2         1  Toy Story (1995)  01-Jan-1995      148       4  877019411
# Star Wars (1977)                    583
# Contact (1997)                      509
# Fargo (1996)                        508
# Return of the Jedi (1983)           507
# Liar Liar (1997)                    485
# English Patient, The (1996)         481
# Scream (1996)                       478
# Toy Story (1995)                    452
# Air Force One (1997)                431
# Independence Day (ID4) (1996)       429
# Raiders of the Lost Ark (1981)      420
# Godfather, The (1972)               413
# Pulp Fiction (1994)                 394
# Twelve Monkeys (1995)               392
# Silence of the Lambs, The (1991)    390
# Jerry Maguire (1996)                384
# Chasing Amy (1997)                  379
# Rock, The (1996)                    378
# Empire Strikes Back, The (1980)     367
# Star Trek: First Contact (1996)     365
# Name: title, dtype: int64
# 405    737
# 655    685
# 13     636
# 450    540
# 276    518
# Name: user_id, dtype: int64
# 4    34174
# 3    27145
# 5    21201
# 2    11370
# 1     6110
# Name: rating, dtype: int64

# %%
n_movies = 100
n_users = 1000
movies = data.title.value_counts()[:n_movies].index.tolist()
users = np.array(data.user_id.value_counts()[:n_users].index.tolist())

rating_matrix = np.zeros((n_movies,n_users))
n_ratings = 0
for ind,movie in enumerate(movies):
    ratings = data[data["title"] == movie]
    rating_matrix[ind,:]= np.mean(ratings['rating']) # Impute mean rating for that movie for all missing ratings
    for index, row in ratings.iterrows():
        user_id = row['user_id']
        if user_id in users:
            rating_matrix[ind,np.where(users == user_id)]= row['rating']
            # print(movie + " user: " + str(user_id) + " rating: " + str(row['rating']))
            n_ratings += 1
print(str(n_ratings) + " observed ratings out of " + str(n_movies*n_users))
print(rating_matrix[:5,:5])
mean_rating = np.mean(rating_matrix)
print(mean_rating)
centered_matrix = rating_matrix - mean_rating
# Out:
# 30055 observed ratings out of 100000
# [[5.         4.         5.         5.         5.        ]
#  [3.80353635 2.         4.         4.         5.        ]
#  [4.15551181 3.         5.         4.         5.        ]
#  [5.         3.         5.         4.         5.        ]
#  [3.15670103 3.         2.         4.         4.        ]]
# 3.8172240137229774

# %%
n_test = 1000
n_val = 1000
n_train = n_ratings - n_test - n_val
full_rating_matrix = np.zeros((n_movies,n_users))
for ind,movie in enumerate(movies):
    ratings = data[data["title"] == movie]
    for index, row in ratings.iterrows():
        user_id = row['user_id']
        if user_id in users:
            full_rating_matrix[ind,np.where(users == user_id)]= row['rating']
nonmissing_indices = np.flatnonzero(full_rating_matrix > 0.1)
aux_ind = nonmissing_indices[np.random.permutation(np.arange(len(nonmissing_indices)))]
test_ind = aux_ind[:n_test]
val_ind = aux_ind[n_test:(n_test+n_val)]
train_ind = aux_ind[(n_test+n_val):(n_test+n_val+n_train)]

train_ratings = full_rating_matrix.flat[train_ind]        
val_ratings = full_rating_matrix.flat[val_ind]
test_ratings = full_rating_matrix.flat[test_ind]

# %%
rating_matrix_ini = np.zeros(full_rating_matrix.shape)
rating_matrix_ini.flat[train_ind] = train_ratings
mean_rating_movie = np.zeros(n_movies)

# Impute mean rating of each movie to fill missing ratings
for ind_movie in range(rating_matrix_ini.shape[0]):
    nonzero_ind = np.nonzero(rating_matrix_ini[ind_movie,:])
    mean_movie = np.mean(rating_matrix_ini[ind_movie,nonzero_ind])
    mean_rating_movie[ind_movie] = mean_movie
    rating_matrix_ini[ind_movie,rating_matrix_ini[ind_movie,:]==0] = mean_movie    
print(rating_matrix_ini[:3,:3])
# Out:
# [[5.         4.         5.        ]
#  [3.79587629 2.         4.        ]
#  [4.16774194 3.         5.        ]]

# %%
def fit_low_rank_model(rank,rating_matrix_ini,train_ind,train_data,n_iter,convergence_thresh,verbose):
    mean_train = np.mean(rating_matrix_ini)
    centered_data = train_data - mean_train
    low_rank_estimate = rating_matrix_ini - mean_train
    previous_fitting_error = 100
    for ind in range(n_iter):
        low_rank_estimate.flat[train_ind] = centered_data
        u, s, vT = np.linalg.svd(low_rank_estimate, full_matrices=True)
        low_rank_estimate = u[:,:rank] @ np.diag(s[:rank]) @ vT[:rank,:]
        fitting_error = np.linalg.norm(centered_data-low_rank_estimate.flat[train_ind]) / np.sqrt(n_train)
        if verbose:
            print("Iteration " + str(ind) + " Error: " + str(fitting_error))
        if np.abs(fitting_error-previous_fitting_error)/previous_fitting_error < convergence_thresh:
            print("Converged after " + str(ind) + " iterations")
            break
        else:
            previous_fitting_error = fitting_error
    return low_rank_estimate + mean_train

n_iter = 5
convergence_thresh = 1e-4
verbose = True
rank = 20
estimate =fit_low_rank_model(rank,rating_matrix_ini,train_ind,train_ratings,n_iter,convergence_thresh,verbose)
estimate[:3,:3]
print(rating_matrix_ini[:3,:3])
print(estimate[:3,:3])
# Out:
# Iteration 0 Error: 0.6524174735728059
# Iteration 1 Error: 0.5835147775176325
# Iteration 2 Error: 0.5457217048390861
# Iteration 3 Error: 0.5212149535257355
# Iteration 4 Error: 0.5039545508128754
# [[5.         4.         5.        ]
#  [3.79587629 2.         4.        ]
#  [4.16774194 3.         5.        ]]
# [[4.92238508 3.85497153 5.62748636]
#  [4.61111445 1.99699612 3.81937084]
#  [7.0813039  3.31345215 3.98795474]]

# %%
ranks = np.arange(1,10,1)
train_error = np.zeros(len(ranks))
val_error = np.zeros(len(ranks))

n_iter = 500
convergence_thresh = 1e-4
verbose = False

for ind,rank in enumerate(ranks):
    print("Rank " + str(rank))
    estimate = fit_low_rank_model(rank,rating_matrix_ini,train_ind,train_ratings,n_iter,convergence_thresh,verbose)
    train_error[ind] = np.linalg.norm(train_ratings-estimate.flat[train_ind]) / np.sqrt(n_train)
    val_error[ind] = np.linalg.norm(val_ratings-estimate.flat[val_ind]) / np.sqrt(n_val)
# Out:
# Rank 1
# Converged after 16 iterations
# Rank 2
# Converged after 27 iterations
# Rank 3
# Converged after 34 iterations
# Rank 4
# Converged after 43 iterations
# Rank 5
# Converged after 53 iterations
# Rank 6
# Converged after 66 iterations
# Rank 7
# Converged after 79 iterations
# Rank 8
# Converged after 94 iterations
# Rank 9
# Converged after 105 iterations

# %%
plt.figure(figsize=(9,9))
plt.plot(ranks,train_error,linestyle="None",marker='o',color='blue',label="Training error")
plt.plot(ranks,val_error,linestyle="None",marker='o',color='black',label="Validation error")
plt.ylabel('Root mean squared error',fontsize=font_size,labelpad=10)
plt.xticks(fontsize=font_size_ticks) 
plt.yticks(fontsize=font_size_ticks)
plt.ylim([0,1.1])
#plt.xlim([0,15])
print(val_error)
# Out:
# [0.95046528 0.90078447 0.88743569 0.91379616 0.9281596  0.97596458
#  1.0179138  1.06033741 1.12362903]

# %%
best_rank = 3
estimate = fit_low_rank_model(best_rank,rating_matrix_ini,train_ind,train_ratings,n_iter,convergence_thresh,verbose)
test_error = np.linalg.norm(test_ratings-estimate.flat[test_ind]) / np.sqrt(n_test)
print("Error of low-rank estimate: " + str(np.round(test_error,3)))
# Out:
# Converged after 34 iterations
# Error of low-rank estimate: 0.891

# %%
mean_rating_estimate = np.tile(np.array([mean_rating_movie]).T,(1,n_users))
print(mean_rating_estimate.shape)
print(mean_rating_estimate[:4,:4])
error_mean_rating = np.linalg.norm(test_ratings-mean_rating_estimate.flat[test_ind]) / np.sqrt(n_test)
print("Error of mean-movie estimate: " + str(np.round(error_mean_rating,3)))
# Out:
# (100, 1000)
# [[4.36247723 4.36247723 4.36247723 4.36247723]
#  [3.79587629 3.79587629 3.79587629 3.79587629]
#  [4.16774194 4.16774194 4.16774194 4.16774194]
#  [4.00847458 4.00847458 4.00847458 4.00847458]]
# Error of mean-movie estimate: 0.969

# %%
centered_estimate = estimate - np.mean(estimate)
u, s, vT = np.linalg.svd(centered_estimate, full_matrices=True)
factor_1 = u[:,0]
factor_2 = u[:,1]
factor_3 = u[:,2]

k=5
print("Factor 1")
sort_1 = np.argsort(factor_1)
for ind in range(3):
    print(movies[sort_1[ind]] + " " + str(np.round(factor_1[sort_1[ind]],3)))
for ind in range(3):
    print(movies[sort_1[ind]] + " " + str(np.round(factor_1[sort_1[-ind]],3)))

print("Factor 2")
sort_2 = np.argsort(factor_2)
for ind in range(3):
    print(movies[sort_2[ind]] + " " + str(np.round(factor_2[sort_2[ind]],3)))

print("Factor 3")
sort_3 = np.argsort(factor_3)
for ind in range(n_movies_plot):
    print(movies[sort_3[ind]] + " " + str(np.round(factor_3[sort_3[ind]],3)))
# Out:
# Factor 1
# Casablanca (1942) -0.13
# Godfather, The (1972) -0.117
# One Flew Over the Cuckoo's Nest (1975) -0.104
# Schindler's List (1993) -0.104
# Usual Suspects, The (1995) -0.102
# Silence of the Lambs, The (1991) -0.1
# To Kill a Mockingbird (1962) -0.098
# Shawshank Redemption, The (1994) -0.092
# Star Wars (1977) -0.087
# Psycho (1960) -0.084
# Amadeus (1984) -0.083
# Pulp Fiction (1994) -0.082
# Fargo (1996) -0.077
# Apocalypse Now (1979) -0.071
# Graduate, The (1967) -0.07
# Clockwork Orange, A (1971) -0.069
# Blade Runner (1982) -0.068
# L.A. Confidential (1997) -0.066
# Monty Python and the Holy Grail (1974) -0.064
# 2001: A Space Odyssey (1968) -0.062
# Princess Bride, The (1987) -0.054
# Raiders of the Lost Ark (1981) -0.053
# Empire Strikes Back, The (1980) -0.053
# Alien (1979) -0.052
# Wizard of Oz, The (1939) -0.052
# Dead Man Walking (1995) -0.052
# It's a Wonderful Life (1946) -0.046
# Sense and Sensibility (1995) -0.039
# Babe (1995) -0.038
# Full Monty, The (1997) -0.037
# Sting, The (1973) -0.036
# GoodFellas (1990) -0.033
# Raising Arizona (1987) -0.033
# Titanic (1997) -0.018
# Trainspotting (1996) -0.015
# Aliens (1986) -0.009
# Fugitive, The (1993) -0.008
# Return of the Jedi (1983) -0.004
# Stand by Me (1986) -0.002
# Terminator, The (1984) -0.002
# Braveheart (1995) -0.002
# Dead Poets Society (1989) -0.0
# When Harry Met Sally... (1989) 0.004
# Fish Called Wanda, A (1988) 0.005
# Leaving Las Vegas (1995) 0.007
# Die Hard (1988) 0.012
# Twelve Monkeys (1995) 0.012
# E.T. the Extra-Terrestrial (1982) 0.012
# Seven (Se7en) (1995) 0.016
# Jaws (1975) 0.017
# Terminator 2: Judgment Day (1991) 0.018
# Four Weddings and a Funeral (1994) 0.023
# Blues Brothers, The (1980) 0.023
# Apollo 13 (1995) 0.025
# Willy Wonka and the Chocolate Factory (1971) 0.026
# Chasing Amy (1997) 0.026
# Star Trek: The Wrath of Khan (1982) 0.029
# Toy Story (1995) 0.029
# Indiana Jones and the Last Crusade (1989) 0.029
# English Patient, The (1996) 0.031
# Groundhog Day (1993) 0.034
# Contact (1997) 0.034
# Forrest Gump (1994) 0.036
# Sound of Music, The (1965) 0.036
# Hunt for Red October, The (1990) 0.04
# Back to the Future (1985) 0.041
# Dances with Wolves (1990) 0.042
# Aladdin (1992) 0.06
# Men in Black (1997) 0.06
# Heat (1995) 0.071
# Jerry Maguire (1996) 0.074
# Star Trek: First Contact (1996) 0.075
# Mr. Holland's Opus (1995) 0.076
# Jurassic Park (1993) 0.08
# Lion King, The (1994) 0.084
# Speed (1994) 0.093
# Birdcage, The (1996) 0.099
# Courage Under Fire (1996) 0.1
# Scream (1996) 0.108
# Truth About Cats & Dogs, The (1996) 0.108
# Rock, The (1996) 0.11
# Game, The (1997) 0.113
# Time to Kill, A (1996) 0.122
# Ransom (1996) 0.131
# Air Force One (1997) 0.133
# In & Out (1997) 0.139
# Top Gun (1986) 0.143
# Phenomenon (1996) 0.156
# Mission: Impossible (1996) 0.161
# Conspiracy Theory (1997) 0.173
# Independence Day (ID4) (1996) 0.174
# Devil's Own, The (1997) 0.181
# Evita (1996) 0.188
# Liar Liar (1997) 0.209
# Broken Arrow (1996) 0.217
# Murder at 1600 (1997) 0.222
# Twister (1996) 0.233
# Saint, The (1997) 0.242
# Volcano (1997) 0.277
# Dante's Peak (1997) 0.287
# Factor 2
# Raiders of the Lost Ark (1981) -0.167
# Star Wars (1977) -0.163
# Titanic (1997) -0.163
# Empire Strikes Back, The (1980) -0.161
# Braveheart (1995) -0.157
# Shawshank Redemption, The (1994) -0.146
# Schindler's List (1993) -0.14
# Forrest Gump (1994) -0.14
# E.T. the Extra-Terrestrial (1982) -0.139
# Back to the Future (1985) -0.137
# Terminator 2: Judgment Day (1991) -0.132
# Return of the Jedi (1983) -0.132
# Dances with Wolves (1990) -0.126
# Princess Bride, The (1987) -0.123
# Wizard of Oz, The (1939) -0.123
# Terminator, The (1984) -0.123
# Fugitive, The (1993) -0.123
# Indiana Jones and the Last Crusade (1989) -0.123
# Usual Suspects, The (1995) -0.121
# It's a Wonderful Life (1946) -0.121
# Game, The (1997) -0.121
# Toy Story (1995) -0.12
# Die Hard (1988) -0.119
# Jaws (1975) -0.118
# Aliens (1986) -0.118
# Jurassic Park (1993) -0.117
# Godfather, The (1972) -0.117
# One Flew Over the Cuckoo's Nest (1975) -0.116
# Casablanca (1942) -0.115
# Aladdin (1992) -0.114
# When Harry Met Sally... (1989) -0.114
# Amadeus (1984) -0.114
# Silence of the Lambs, The (1991) -0.112
# Contact (1997) -0.111
# Sting, The (1973) -0.108
# Monty Python and the Holy Grail (1974) -0.107
# Dead Poets Society (1989) -0.107
# Pulp Fiction (1994) -0.106
# Alien (1979) -0.105
# Lion King, The (1994) -0.105
# Mr. Holland's Opus (1995) -0.104
# Hunt for Red October, The (1990) -0.103
# Stand by Me (1986) -0.103
# Top Gun (1986) -0.103
# Star Trek: The Wrath of Khan (1982) -0.1
# Fargo (1996) -0.1
# L.A. Confidential (1997) -0.1
# Speed (1994) -0.099
# Apollo 13 (1995) -0.098
# Graduate, The (1967) -0.098
# GoodFellas (1990) -0.097
# Rock, The (1996) -0.095
# Time to Kill, A (1996) -0.095
# Men in Black (1997) -0.095
# Blues Brothers, The (1980) -0.095
# To Kill a Mockingbird (1962) -0.094
# Apocalypse Now (1979) -0.094
# Star Trek: First Contact (1996) -0.094
# Psycho (1960) -0.092
# Air Force One (1997) -0.092
# Groundhog Day (1993) -0.091
# Seven (Se7en) (1995) -0.091
# Independence Day (ID4) (1996) -0.09
# Chasing Amy (1997) -0.088
# Jerry Maguire (1996) -0.087
# Fish Called Wanda, A (1988) -0.086
# Sound of Music, The (1965) -0.085
# Scream (1996) -0.084
# Sense and Sensibility (1995) -0.08
# 2001: A Space Odyssey (1968) -0.079
# Babe (1995) -0.078
# Courage Under Fire (1996) -0.077
# Willy Wonka and the Chocolate Factory (1971) -0.075
# Blade Runner (1982) -0.074
# Twelve Monkeys (1995) -0.072
# Dead Man Walking (1995) -0.071
# English Patient, The (1996) -0.069
# Ransom (1996) -0.068
# Phenomenon (1996) -0.068
# Heat (1995) -0.066
# Birdcage, The (1996) -0.062
# Truth About Cats & Dogs, The (1996) -0.06
# Twister (1996) -0.058
# Raising Arizona (1987) -0.057
# Leaving Las Vegas (1995) -0.053
# Full Monty, The (1997) -0.053
# Mission: Impossible (1996) -0.049
# Four Weddings and a Funeral (1994) -0.044
# Clockwork Orange, A (1971) -0.042
# In & Out (1997) -0.04
# Liar Liar (1997) -0.036
# Conspiracy Theory (1997) -0.036
# Trainspotting (1996) -0.032
# Saint, The (1997) -0.021
# Broken Arrow (1996) -0.019
# Devil's Own, The (1997) 0.012
# Murder at 1600 (1997) 0.035
# Dante's Peak (1997) 0.035
# Evita (1996) 0.051
# Volcano (1997) 0.066
# Factor 3
# Clockwork Orange, A (1971) -0.303
# Trainspotting (1996) -0.285
# Leaving Las Vegas (1995) -0.283
# English Patient, The (1996) -0.253
# Chasing Amy (1997) -0.237
# Evita (1996) -0.225
# Pulp Fiction (1994) -0.219
# Dead Man Walking (1995) -0.187
# Raising Arizona (1987) -0.174
# Full Monty, The (1997) -0.154
# Apocalypse Now (1979) -0.153
# Birdcage, The (1996) -0.149
# GoodFellas (1990) -0.149
# In & Out (1997) -0.136
# Fargo (1996) -0.121
# Graduate, The (1967) -0.116
# Four Weddings and a Funeral (1994) -0.109
# 2001: A Space Odyssey (1968) -0.107
# Seven (Se7en) (1995) -0.107
# Willy Wonka and the Chocolate Factory (1971) -0.105
# Scream (1996) -0.097
# Godfather, The (1972) -0.087
# Heat (1995) -0.084
# Twelve Monkeys (1995) -0.081
# Psycho (1960) -0.081
# Truth About Cats & Dogs, The (1996) -0.07
# Devil's Own, The (1997) -0.066
# Fish Called Wanda, A (1988) -0.061
# Stand by Me (1986) -0.059
# L.A. Confidential (1997) -0.056
# One Flew Over the Cuckoo's Nest (1975) -0.052
# Broken Arrow (1996) -0.045
# Volcano (1997) -0.045
# Blade Runner (1982) -0.043
# Dante's Peak (1997) -0.042
# Jaws (1975) -0.04
# Monty Python and the Holy Grail (1974) -0.038
# Alien (1979) -0.034
# Sense and Sensibility (1995) -0.032
# Courage Under Fire (1996) -0.024
# Contact (1997) -0.022
# Mission: Impossible (1996) -0.022
# Babe (1995) -0.022
# Amadeus (1984) -0.02
# Game, The (1997) -0.018
# Aliens (1986) -0.014
# Liar Liar (1997) -0.012
# Dances with Wolves (1990) -0.012
# Murder at 1600 (1997) -0.011
# Jerry Maguire (1996) -0.01
# Wizard of Oz, The (1939) -0.006
# When Harry Met Sally... (1989) -0.001
# Phenomenon (1996) -0.001
# Casablanca (1942) 0.0
# Saint, The (1997) 0.001
# Silence of the Lambs, The (1991) 0.001
# E.T. the Extra-Terrestrial (1982) 0.002
# Ransom (1996) 0.009
# Die Hard (1988) 0.015
# Usual Suspects, The (1995) 0.015
# Star Trek: The Wrath of Khan (1982) 0.02
# Dead Poets Society (1989) 0.021
# Rock, The (1996) 0.021
# Twister (1996) 0.022
# Groundhog Day (1993) 0.023
# Time to Kill, A (1996) 0.025
# Speed (1994) 0.027
# Mr. Holland's Opus (1995) 0.028
# To Kill a Mockingbird (1962) 0.028
# Terminator, The (1984) 0.029
# Top Gun (1986) 0.029
# Blues Brothers, The (1980) 0.03
# Toy Story (1995) 0.037
# Sting, The (1973) 0.044
# Back to the Future (1985) 0.045
# Forrest Gump (1994) 0.047
# Men in Black (1997) 0.053
# Aladdin (1992) 0.054
# Star Trek: First Contact (1996) 0.055
# Schindler's List (1993) 0.057
# Shawshank Redemption, The (1994) 0.062
# Lion King, The (1994) 0.063
# Apollo 13 (1995) 0.065
# Fugitive, The (1993) 0.067
# Conspiracy Theory (1997) 0.067
# Sound of Music, The (1965) 0.07
# Terminator 2: Judgment Day (1991) 0.073
# Princess Bride, The (1987) 0.076
# Jurassic Park (1993) 0.077
# Air Force One (1997) 0.078
# Independence Day (ID4) (1996) 0.087
# Hunt for Red October, The (1990) 0.096
# Braveheart (1995) 0.097
# Indiana Jones and the Last Crusade (1989) 0.098
# It's a Wonderful Life (1946) 0.106
# Empire Strikes Back, The (1980) 0.116
# Titanic (1997) 0.121
# Raiders of the Lost Ark (1981) 0.125
# Star Wars (1977) 0.128
# Return of the Jedi (1983) 0.138
